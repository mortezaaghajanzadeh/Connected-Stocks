# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib as plt
import re as ree
import requests
import csv
import datetime
import time
import random

# %%
def vv4(row):
    row = str(row)
    X = [1,1,1]
    X[0] = row[0:4]
    X[1] = row[4:6]
    X[2] = row[6:8]
    return X[0]+'-'+X[1]+'-'+X[2]

def vv(row):
    X = row.split('-')
    return X[0]+X[1]+X[2]

def DriveYearMonthDay(d):
    d['jalaliDate'] = d['jalaliDate'].astype(str)
    d['Year'] = d['jalaliDate'].str[0:4]
    d['Month'] = d['jalaliDate'].str[4:6]
    d['Day'] = d['jalaliDate'].str[6:8]
    d['jalaliDate'] = d['jalaliDate'].astype(int)
    return d

def convert_ar_characters(input_str):

    mapping = {
        'ك': 'ک',
        'گ':'گ',
        'دِ': 'د',
        'بِ': 'ب',
        'زِ': 'ز',
        'ذِ': 'ذ',
        'شِ': 'ش',
        'سِ': 'س',
        'ى': 'ی',
        'ي': 'ی'
    }
    return _multiple_replace(mapping, input_str)


def _multiple_replace(mapping, text):
    pattern = "|".join(map(ree.escape, mapping.keys()))
    return ree.sub(pattern, lambda m: mapping[m.group()], str(text))
def vv2(row):
    X = row.split('/')
    return X[0]+X[1]+X[2]
def vv3(row):
    X = row.split('/')
    if len(X[0])<4:
        X[0] = '13' + X[0]
    if len(X[1])<2:
        X[1] = '0'+X[1]
    if len(X[2])<2:
        X[2] = '0'+X[2]
    return X[0]+X[1]+X[2]

# %%
path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data\\"

# %%
# path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data"

n = path + 'Cleaned_Stocks_Holders_1399-09-12_From94.csv'
df = pd.read_csv(n)

df = df.drop(df.loc[df['Holder']=='شخص حقیقی'].index)
df = df.drop(df[(df['Trade']=='No')&((df['close_price']==10)|(df['close_price']==1000)|(df['close_price']==10000)|(df['close_price']==100000))].index)
df = df.drop(df[(df['symbol'] == 'وقوام')&(df['close_price'] == 1000)].index)
symbols = [ 'سپرده','هما','وهنر-پذیره','نکالا','تکالا','اکالا','توسعه گردشگری ','وآفر','ودانا','نشار','نبورس','چبسپا','بدکو','چکارم','تراک','کباده','فبستم','تولیددارو','قیستو','خلیبل','پشاهن','قاروم','هوایی سامان','کورز','شلیا','دتهران','نگین','کایتا','غیوان','تفیرو','سپرمی','بتک']
df = df.drop(df[df['symbol'].isin(symbols)].index)
df = df.drop(df[df.group_name== 'صندوق سرمایه گذاری قابل معامله'].index)
df = df.drop(df[(df.symbol == 'اتکای')&(df.close_price == 1000)].index)

# %%
mlist = ['کارگزاری بانک انصار',
'تعاونی مصرف کارکنان بانک انصار',
'وقوام','حکمت',
 'صندوق سرمایه گذاری کارکنان حکمت',
'سرمایه گذاری مهر اقتصاد ایرانیان',
'گروه مالی مهر اقتصاد',
'وکوثر','کوثر',
'سرمایه گذاری الماس حکمت ایرانیان',
        "کارگزاری بانک سپه",
        'بانک سپه']

# %%
HolderData = df[(df.Holder.isin(mlist))]

# %%
mlist1 = ["کارگزاری بانک سپه", 'بانک سپه']
Ssymbol = set(df[(df.Holder.isin(mlist1))].symbol)
mlist2 = ['کارگزاری بانک انصار',
'تعاونی مصرف کارکنان بانک انصار',
'وقوام','حکمت',
 'صندوق سرمایه گذاری کارکنان حکمت',
'سرمایه گذاری مهر اقتصاد ایرانیان',
'گروه مالی مهر اقتصاد',
'وکوثر','کوثر',
'سرمایه گذاری الماس حکمت ایرانیان']
Osymbol = set(df[(df.Holder.isin(mlist2))].symbol)

# %%
# path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data"

n1 = path + 'Stocks_Prices_1399-09-12' + '.csv'
df1 = pd.read_csv(n1)

df1['jalaliDate'] = df1['jalaliDate'].apply(vv)
df = df1
symbols = [ 'سپرده','هما','وهنر-پذيره','نکالا','تکالا','اکالا','توسعه گردشگری ','وآفر','ودانا','نشار','نبورس','چبسپا','بدکو','چکارم','تراک','کباده','فبستم','تولیددارو','قیستو','خلیبل','پشاهن','قاروم','هوایی سامان','کورز','شلیا','دتهران','نگین','کایتا','غیوان','تفیرو','سپرمی','بتک']
df = df.drop(df[df['name'].isin(symbols)].index)
df = df.drop(df[df.group_name== 'صندوق سرمایه گذاری قابل معامله'].index)

df['name'] = df['name'].apply(lambda x: convert_ar_characters(x))
slist = set(HolderData.symbol)

df = df[df.name.isin(slist)]
df = df.drop_duplicates()
df = df.drop(df.loc[(df['volume'] == 0)].index).sort_values(by =['name','jalaliDate']).drop(columns = ['volume','quantity']).rename(columns = {'name':'symbol'})
df = DriveYearMonthDay(df)

# %%
PriceData = pd.DataFrame()
PriceData = PriceData.append(df[['jalaliDate', 'date', 'symbol','close_price','group_id']])
PriceData['date1'] = PriceData['date'].apply(vv4)
PriceData['date1'] = pd.to_datetime(PriceData['date1']) 
PriceData['week_of_year'] = PriceData['date1'].dt.week 
PriceData['year_of_year'] = PriceData['date1'].dt.year
gg =PriceData.groupby('symbol')
PriceData['Ret'] = gg['close_price'].pct_change(periods = 1)*100
PriceData.head()
# Out:
#         jalaliDate      date  symbol  close_price  group_id      date1  \
# 421977    13811207  20030226  آکنتور       8000.0        33 2003-02-26
# 421976    13811210  20030301  آکنتور       8000.0        33 2003-03-01
# 421975    13811211  20030302  آکنتور       8000.0        33 2003-03-02
# 421974    13811212  20030303  آکنتور       8000.0        33 2003-03-03
# 421973    13811213  20030304  آکنتور       8000.0        33 2003-03-04
#
#         week_of_year  year_of_year  Ret
# 421977             9          2003  NaN
# 421976             9          2003  0.0
# 421975             9          2003  0.0
# 421974            10          2003  0.0
# 421973            10          2003  0.0

# %%
n = path + 'Factors-Daily.xlsx'
Factors = pd.read_excel(n)

# %%
Factors.tail()
# Out:
#       jalaliDate      date       SMB       HML  Winner_Loser  Market_return
# 2882    13990908  20201128 -0.680105 -1.598209      1.435511       1.728555
# 2883    13990909  20201129 -1.619483 -0.646124     -0.366239       2.616847
# 2884    13990910  20201130 -1.062186  1.714601     -0.160517       2.714100
# 2885    13990911  20201201 -0.595752  0.555956     -0.071474       0.529881
# 2886    13990912  20201202  0.351218 -0.764257      0.124712      -0.185540

# %%
PriceData = PriceData.merge(Factors,on = ['jalaliDate','date']).sort_values(by =['symbol','date']).reset_index(drop=True).dropna()

# %%
PriceData.head()
# Out:
#    jalaliDate      date  symbol  close_price  group_id      date1  \
# 0    13870926  20081216  آکنتور       3813.0        33 2008-12-16
# 1    13871003  20081223  آکنتور       3810.0        33 2008-12-23
# 2    13871007  20081227  آکنتور       3809.0        33 2008-12-27
# 3    13871008  20081228  آکنتور       3809.0        33 2008-12-28
# 4    13871010  20081230  آکنتور       3695.0        33 2008-12-30
#
#    week_of_year  year_of_year       Ret       SMB       HML  Winner_Loser  \
# 0            51          2008 -2.977099  0.415223  0.220430     -1.330472
# 1            52          2008 -0.078678  0.652585  0.126558     -0.963050
# 2            52          2008 -0.026247 -1.028476  0.597590     -0.496629
# 3            52          2008  0.000000  0.058510  0.448855     -0.711369
# 4             1          2008 -2.992912  0.518573  0.801864     -0.546160
#
#    Market_return
# 0      -0.244075
# 1      -0.326080
# 2      -0.102323
# 3      -0.328906
# 4      -0.365536

# %%
n = path + 'RiskFree.xlsx'
df3 = pd.read_excel(n)
df3 = df3.rename(columns = {'Unnamed: 2' : 'Year'})
df3['YM'] = df3['YM'].astype(str)
df3['YM'] = df3['YM'] + '00'
df3['YM'] = df3['YM'].astype(int)
df4 = PriceData
df4['RiskFree'] = np.nan
df4['jalaliDate'] = df4['jalaliDate'].astype(int)
for i in df3.YM:
    df4.loc[df4.jalaliDate>= i,'RiskFree'] = df3.loc[df3['YM'] == i ].iloc[0,1]/12/52/7

# %%
PriceData = df4
PriceData['EMarketRet'] = PriceData['Market_return'] - PriceData['RiskFree']
PriceData['ERet'] = PriceData['Ret'] - PriceData['RiskFree']

# %%
PriceData.head()
# Out:
#    jalaliDate      date  symbol  close_price  group_id      date1  \
# 0    13870926  20081216  آکنتور       3813.0        33 2008-12-16
# 1    13871003  20081223  آکنتور       3810.0        33 2008-12-23
# 2    13871007  20081227  آکنتور       3809.0        33 2008-12-27
# 3    13871008  20081228  آکنتور       3809.0        33 2008-12-28
# 4    13871010  20081230  آکنتور       3695.0        33 2008-12-30
#
#    week_of_year  year_of_year       Ret       SMB       HML  Winner_Loser  \
# 0            51          2008 -2.977099  0.415223  0.220430     -1.330472
# 1            52          2008 -0.078678  0.652585  0.126558     -0.963050
# 2            52          2008 -0.026247 -1.028476  0.597590     -0.496629
# 3            52          2008  0.000000  0.058510  0.448855     -0.711369
# 4             1          2008 -2.992912  0.518573  0.801864     -0.546160
#
#    Market_return  RiskFree  EMarketRet      ERet
# 0      -0.244075  0.003434   -0.247509 -2.980533
# 1      -0.326080  0.003434   -0.329514 -0.082112
# 2      -0.102323  0.003434   -0.105757 -0.029681
# 3      -0.328906  0.003434   -0.332340 -0.003434
# 4      -0.365536  0.003434   -0.368971 -2.996346

# %%
len(set(PriceData.symbol))
# Out:
# 38

# %%
n1 = path + "Industry indexes 1399-09-28.csv"
df1 = pd.read_csv(n1)
df1.date = df1.date.apply(vv3)
df1 = df1.drop(columns = ['Unnamed: 0'])
df1 = df1.drop(df1[(df1.index_id == 'EWI')|(df1.index_id == 'overall_index')].index)
df1.index_id = df1.index_id.astype(int)
df1.date = df1.date.astype(int)
gg = df1.groupby('index_id')
df1['gReturn'] = gg['index'].pct_change(periods = 1)*100
fkey = zip(list(df1.index_id),list(df1.date))
mapingdict = dict(zip(fkey,df1['gReturn']))
PriceData['gEReturn'] = PriceData.set_index(['group_id','jalaliDate']).index.map(mapingdict)
PriceData['gEReturn'] = PriceData['gEReturn'] -  PriceData['RiskFree']

# %%
wg = PriceData.groupby(['symbol'])
def FourFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','HML','SMB','Winner_Loser']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['4-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['HML']  + model.params[3]*g['SMB']  + model.params[4]*g['Winner_Loser']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

def FiveFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','HML','SMB','Winner_Loser','gEReturn']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['5-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['HML']  + model.params[3]*g['SMB']  + model.params[4]*g['Winner_Loser'] + model.params[5]*g['gEReturn']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

def TwoFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','gEReturn']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['2-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['gEReturn']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

re = wg.apply(FourFactor)
print('Fourfactor done')
re2 = wg.apply(FiveFactor)
re['5-Residual'] = re2['5-Residual']
print('Fivefactor done')

re2 = wg.apply(TwoFactor)
re['2-Residual'] = re2['2-Residual']
print('Twofactor done')

re = re.reset_index(drop=True)
col = 'symbol'
re[col] = re[col].apply(lambda x: convert_ar_characters(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Fourfactor done
# Fivefactor done
# Twofactor done

# %%
residuals = re[re.jalaliDate>13940000]

# %%
A = set(residuals.symbol)
len(set(residuals.symbol))
# Out:
# 38

# %%
C = set(HolderData.symbol)
len(set(HolderData.symbol))
# Out:
# 38

# %%
# HolderData = df

# %%
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['4-Residual']))
HolderData['4-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('4-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['5-Residual']))
HolderData['5-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('5-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['2-Residual']))
HolderData['2-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('2-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['Ret']))
HolderData['Ret'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('Ret done')
# Out:
# 4-Residual done
# 5-Residual done
# 2-Residual done
# Ret done

# %%
HolderData = HolderData.drop(HolderData[HolderData['4-Residual'].isnull()].index)

# %%
len(HolderData)
# [HolderData['4-Residual'].isnull()]
# Out:
# 12529

# %%
B = set(HolderData.symbol)
len(set(HolderData.symbol))
# Out:
# 38

# %%
HolderData.jalaliDate.iloc[0]
# Out:
# 13940431

# %%
df = HolderData

# %%
Holders = list(set(df.Holder))
Holders.sort()
ids = list(range(len(Holders)))
mapingdict = dict(zip(Holders, ids))
df['Holder_id'] = df['Holder'].map(mapingdict)

symbols = list(set(df.symbol))
symbols.sort()
ids = list(range(len(symbols)))
mapingdict = dict(zip(symbols, ids))
df['id'] = df['symbol'].map(mapingdict)

# %%
df['date1'] = df['date'].apply(vv4)
df['date1'] = pd.to_datetime(df['date1']) 
df['week_of_year'] = df['date1'].dt.week 
df['month_of_year'] = df['date1'].dt.month 
df['year_of_year'] = df['date1'].dt.year

# %%
df['MarketCap'] = df['close_price'] * df['shrout']

# %%
market = df.groupby(['date','symbol']).first().reset_index()[['jalaliDate','date','symbol','MarketCap']]
gm = market.groupby(['date'])

market['Percentile_Rank'] = gm.MarketCap.rank(pct = True) 
fkey = zip(list(market.symbol),list(market.date))
mapingdict = dict(zip(fkey,market['Percentile_Rank']))
df['Percentile_Rank'] = df.set_index(['symbol','date']).index.map(mapingdict)

# %%
df.head()
# Out:
#            date  jalaliDate  symbol      stock_id  \
# 69831  20150722    13940431  آکنتور  4.483485e+16
# 69836  20150725    13940503  آکنتور  4.483485e+16
# 69840  20150726    13940504  آکنتور  4.483485e+16
# 69844  20150727    13940505  آکنتور  4.483485e+16
# 69848  20150728    13940506  آکنتور  4.483485e+16
#
#                              group_name  group_id Holder    nshares  type  \
# 69831  ابزارپزشکی، اپتیکی و اندازه‌گیری      33.0  وقوام  3270713.0  bank
# 69836  ابزارپزشکی، اپتیکی و اندازه‌گیری      33.0  وقوام  4380318.0  bank
# 69840  ابزارپزشکی، اپتیکی و اندازه‌گیری      33.0  وقوام  6038636.0  bank
# 69844  ابزارپزشکی، اپتیکی و اندازه‌گیری      33.0  وقوام  6038636.0  bank
# 69848  ابزارپزشکی، اپتیکی و اندازه‌گیری      33.0  وقوام  6182567.0  bank
#
#        Percent  ...  2-Residual       Ret Holder_id id      date1  \
# 69831     1.63  ...    0.140888  4.041064         3  0 2015-07-22
# 69836     2.19  ...    0.044728  0.932903         3  0 2015-07-25
# 69840     3.01  ...    0.100663  2.017419         3  0 2015-07-26
# 69844     3.01  ...   -0.053479 -3.205854         3  0 2015-07-27
# 69848     3.09  ...    0.021860 -1.935019         3  0 2015-07-28
#
#       week_of_year  month_of_year  year_of_year     MarketCap  Percentile_Rank
# 69831           30              7          2015  2.229600e+12         0.555556
# 69836           30              7          2015  2.250400e+12         0.555556
# 69840           30              7          2015  2.295800e+12         0.400000
# 69844           31              7          2015  2.222200e+12         0.454545
# 69848           31              7          2015  2.179200e+12         0.500000
#
# [5 rows x 28 columns]

# %%
df.head()
df.loc[df.week_of_year%2 == 1,'week_of_year'] = df.loc[df.week_of_year%2 == 1]['week_of_year']-1

# %%
    def MonthlyCorr(f):
        
        fc = f.groupby(['year_of_year','month_of_year'])[['2-Residual_x','2-Residual_y',
                                                          '4-Residual_x','4-Residual_y',
                                                          '5-Residual_x','5-Residual_y']].corr().reset_index()
        
        TwoCor = fc.loc[fc.level_2 == '2-Residual_y'][['year_of_year','month_of_year',
                                                       '2-Residual_x']].rename(columns = {'2-Residual_x':'ρ_2'})
        FourCor = fc.loc[fc.level_2 == '4-Residual_y'][['year_of_year','month_of_year',
                                                        '4-Residual_x']].rename(columns = {'4-Residual_x':'ρ_4'})
        ThreeCor = fc.loc[fc.level_2 == '5-Residual_y'][['year_of_year','month_of_year',
                                                         '5-Residual_x']].rename(columns = {'5-Residual_x':'ρ_5'})
        
        TimeId = zip(list(TwoCor.year_of_year),list(TwoCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(TwoCor.ρ_2)))
        f['Monthlyρ_2'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(FourCor.year_of_year),list(FourCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(FourCor.ρ_4)))
        f['Monthlyρ_4'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(ThreeCor.year_of_year),list(ThreeCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(ThreeCor.ρ_5)))
        f['Monthlyρ_5'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict) 
        return f
    
            
    def MonthlyCalculation(f):
    
        f = MonthlyCorr(f)        
        
        ff = f.groupby(['year_of_year','month_of_year'])[['SizeRatio','MarketCap_x',
                                                          'MarketCap_y','Percentile_Rank_x',
                                                       'Percentile_Rank_y','size1','size2',
                                                          'SameSize']].mean().reset_index()
        
        vlist = ['SizeRatio', 'MarketCap_x','MarketCap_y', 'Percentile_Rank_x', 'Percentile_Rank_y', 'size1',
               'size2', 'SameSize']
        
        for i in vlist:
            TimeId = zip(list(ff.year_of_year),list(ff.month_of_year))
            mapingdict = dict(zip(TimeId,list(ff[i])))
            f['Monthly'+i] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        mfcapf =  f.groupby(['year_of_year','month_of_year'])['FCAPf','FCA'].mean().reset_index()
        TimeId = zip(list(mfcapf.year_of_year),list(mfcapf.month_of_year))
        mapingdict = dict(zip(TimeId,list(mfcapf.FCAPf)))
        f['MonthlyFCAPf'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        TimeId = zip(list(mfcapf.year_of_year),list(mfcapf.month_of_year))
        mapingdict = dict(zip(TimeId,list(mfcapf.FCA)))
        f['MonthlyFCA'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
                
        f['Monthlyρ_2_f'] = f['Monthlyρ_2'].shift(-1)
        f['Monthlyρ_4_f'] = f['Monthlyρ_4'].shift(-1)
        f['Monthlyρ_5_f'] = f['Monthlyρ_5'].shift(-1)
        return f

# %%
    def WeeklyCorr(f):
        fc = f.groupby(['year_of_year','week_of_year'])[['2-Residual_x','2-Residual_y',
                                                         '4-Residual_x','4-Residual_y',
                                                         '5-Residual_x','5-Residual_y']].corr().reset_index()
        
        TwoCor = fc.loc[fc.level_2 == '2-Residual_y'][['year_of_year','week_of_year',
                                                        '2-Residual_x']].rename(columns = {'2-Residual_x':'ρ_2'})
        FourCor = fc.loc[fc.level_2 == '4-Residual_y'][['year_of_year','week_of_year',
                                                        '4-Residual_x']].rename(columns = {'4-Residual_x':'ρ_4'})
        ThreeCor = fc.loc[fc.level_2 == '5-Residual_y'][['year_of_year','week_of_year',
                                                         '5-Residual_x']].rename(columns = {'5-Residual_x':'ρ_5'})
        
        TimeId = zip(list(TwoCor.year_of_year),list(TwoCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(TwoCor.ρ_2)))
        f['Weeklyρ_2'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(FourCor.year_of_year),list(FourCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(FourCor.ρ_4)))
        f['Weeklyρ_4'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(ThreeCor.year_of_year),list(ThreeCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(ThreeCor.ρ_5)))
        f['Weeklyρ_5'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        return f
    
        
    def WeeklyCalculation(f):
        
        f = WeeklyCorr(f)


        ff = f.groupby(['year_of_year','week_of_year'])[['SizeRatio','MarketCap_x','MarketCap_y','Percentile_Rank_x',
                                                       'Percentile_Rank_y','size1','size2','SameSize']].mean().reset_index()
        
        vlist = ['SizeRatio', 'MarketCap_x','MarketCap_y', 'Percentile_Rank_x', 'Percentile_Rank_y', 'size1',
               'size2', 'SameSize']
        
        for i in vlist:
            TimeId = zip(list(ff.year_of_year),list(ff.week_of_year))
            mapingdict = dict(zip(TimeId,list(ff[i])))
            f['Weekly'+i] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict) 



        wfcapf =  f.groupby(['year_of_year','week_of_year'])['FCAPf','FCA'].mean().reset_index()
        TimeId = zip(list(wfcapf.year_of_year),list(wfcapf.week_of_year))
        mapingdict = dict(zip(TimeId,list(wfcapf.FCAPf)))
        f['WeeklyFCAPf'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)  
        TimeId = zip(list(wfcapf.year_of_year),list(wfcapf.week_of_year))
        mapingdict = dict(zip(TimeId,list(wfcapf.FCA)))
        f['WeeklyFCA'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict) 
        f['Weeklyρ_2_f'] = f['Weeklyρ_2'].shift(-1)
        f['Weeklyρ_4_f'] = f['Weeklyρ_4'].shift(-1)
        f['Weeklyρ_5_f'] = f['Weeklyρ_5'].shift(-1)
        return f

# %%
def FCalculatio(a,g,S_g):
    if len(a) == 0:
        a = pd.DataFrame()
        return a
    else: 
        a['FCAPf'] = (a['nshares_x']*a['close_price_x'] + a['nshares_y']*a['close_price_y'])/(a['shrout_x']*a['close_price_x'] + a['shrout_y']*a['close_price_y'])
        a['FCA'] = ((a['nshares_x']*a['close_price_x'])**0.5 + (a['nshares_y']*a['close_price_y'])**0.5)/((a['shrout_x']*a['close_price_x'])**0.5 + (a['shrout_y']*a['close_price_y'])**0.5)
    return a

# %%
    def Calculation(g,S_g):
        intersection = list(set.intersection(set(S_g.date), set(g.date)))
        g = g.loc[g.date.isin(intersection)]
        S_g = S_g.loc[S_g.date.isin(intersection)]
        a = g.merge(S_g , on = ['date','jalaliDate','week_of_year','month_of_year','year_of_year'])
        a = FCalculatio(a,g,S_g)
        if len(a) == 0:
            f = pd.DataFrame()
            return f
        a['SizeRatio'] = (a['MarketCap_x'])/(a['MarketCap_y'])
        f = a.groupby(['date','jalaliDate','id_x','id_y','week_of_year','month_of_year','year_of_year',
                           'group_name_x','group_name_y','Ret_x','Ret_y','SizeRatio','MarketCap_x',
                           'MarketCap_y','2-Residual_x','2-Residual_y','4-Residual_x','4-Residual_y',
                           '5-Residual_x','5-Residual_y','Percentile_Rank_x','Percentile_Rank_y'])['FCAPf','FCA'].sum().reset_index()
        f['FCA'] = f['FCA']**2
        f['size1'] = 0
        f.loc[f.MarketCap_x>f.MarketCap_y,'size1'] = f[f.MarketCap_x>f.MarketCap_y]['Percentile_Rank_x']
        f.loc[f.MarketCap_x<f.MarketCap_y,'size1'] = f[f.MarketCap_x<f.MarketCap_y]['Percentile_Rank_y']
        f['size2'] = 0
        f.loc[f.MarketCap_x>f.MarketCap_y,'size2'] = f[f.MarketCap_x>f.MarketCap_y]['Percentile_Rank_y']
        f.loc[f.MarketCap_x<f.MarketCap_y,'size2'] = f[f.MarketCap_x<f.MarketCap_y]['Percentile_Rank_x']
        f['SameSize'] =  f['size2'] -f['size1']
        f['sgroup'] = 0
        f.loc[f.group_name_x == f.group_name_y,'sgroup'] = 1
        return f

# %%
gdata = df.groupby(['id'])
g = gdata.get_group(0)
S_g = gdata.get_group(1)

def FCAPf(S_g,g):
    intersection = list(set.intersection(set(S_g.date), set(g.date)))
    if len(intersection) == 0 :
#         print('0')
        return
    f= Calculation(g,S_g)
    if len (f) == 0:
#         print("No")
        return
    f = MonthlyCalculation(f)        
    f = WeeklyCalculation(f)
    return f

FCAPf(S_g,g)
# Out:
#         date  jalaliDate  id_x  id_y  week_of_year  month_of_year  \
# 0   20150722    13940431     0     1            30              7
# 1   20150725    13940503     0     1            30              7
# 2   20150726    13940504     0     1            30              7
# 3   20150727    13940505     0     1            30              7
# 4   20150728    13940506     0     1            30              7
# 5   20150729    13940507     0     1            30              7
# 6   20150801    13940510     0     1            30              8
# 7   20150802    13940511     0     1            30              8
# 8   20150803    13940512     0     1            32              8
# 9   20150804    13940513     0     1            32              8
# 10  20150805    13940514     0     1            32              8
# 11  20150808    13940517     0     1            32              8
# 12  20150809    13940518     0     1            32              8
# 13  20150810    13940519     0     1            32              8
# 14  20150812    13940521     0     1            32              8
# 15  20150815    13940524     0     1            32              8
# 16  20150816    13940525     0     1            32              8
# 17  20150817    13940526     0     1            34              8
# 18  20150818    13940527     0     1            34              8
# 19  20151114    13940823     0     1            46             11
# 20  20151115    13940824     0     1            46             11
# 21  20151116    13940825     0     1            46             11
# 22  20151117    13940826     0     1            46             11
# 23  20151118    13940827     0     1            46             11
# 24  20151121    13940830     0     1            46             11
# 25  20151122    13940901     0     1            46             11
# 26  20151123    13940902     0     1            48             11
# 27  20151124    13940903     0     1            48             11
# 28  20151125    13940904     0     1            48             11
# 29  20151128    13940907     0     1            48             11
# 30  20151129    13940908     0     1            48             11
# 31  20151130    13940909     0     1            48             11
# 32  20151201    13940910     0     1            48             12
# 33  20151205    13940914     0     1            48             12
# 34  20151206    13940915     0     1            48             12
# 35  20151207    13940916     0     1            50             12
# 36  20151208    13940917     0     1            50             12
# 37  20151209    13940918     0     1            50             12
# 38  20151213    13940922     0     1            50             12
# 39  20151214    13940923     0     1            50             12
# 40  20151215    13940924     0     1            50             12
# 41  20151216    13940925     0     1            50             12
# 42  20151219    13940928     0     1            50             12
# 43  20151220    13940929     0     1            50             12
# 44  20151221    13940930     0     1            52             12
# 45  20151222    13941001     0     1            52             12
# 46  20151223    13941002     0     1            52             12
# 47  20151226    13941005     0     1            52             12
# 48  20151227    13941006     0     1            52             12
# 49  20151228    13941007     0     1            52             12
#
#     year_of_year                      group_name_x  \
# 0           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 1           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 2           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 3           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 4           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 5           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 6           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 7           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 8           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 9           2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 10          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 11          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 12          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 13          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 14          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 15          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 16          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 17          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 18          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 19          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 20          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 21          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 22          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 23          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 24          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 25          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 26          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 27          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 28          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 29          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 30          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 31          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 32          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 33          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 34          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 35          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 36          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 37          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 38          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 39          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 40          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 41          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 42          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 43          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 44          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 45          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 46          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 47          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 48          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
# 49          2015  ابزارپزشکی، اپتیکی و اندازه‌گیری
#
#                     group_name_y     Ret_x  ...  WeeklyPercentile_Rank_x  \
# 0   ماشین آلات و دستگاه‌های برقی  4.041064  ...                 0.479609
# 1   ماشین آلات و دستگاه‌های برقی  0.932903  ...                 0.479609
# 2   ماشین آلات و دستگاه‌های برقی  2.017419  ...                 0.479609
# 3   ماشین آلات و دستگاه‌های برقی -3.205854  ...                 0.479609
# 4   ماشین آلات و دستگاه‌های برقی -1.935019  ...                 0.479609
# 5   ماشین آلات و دستگاه‌های برقی  3.882159  ...                 0.479609
# 6   ماشین آلات و دستگاه‌های برقی -2.765262  ...                 0.479609
# 7   ماشین آلات و دستگاه‌های برقی -1.980738  ...                 0.479609
# 8   ماشین آلات و دستگاه‌های برقی -0.259548  ...                 0.446128
# 9   ماشین آلات و دستگاه‌های برقی -2.304833  ...                 0.446128
# 10  ماشین آلات و دستگاه‌های برقی  0.542237  ...                 0.446128
# 11  ماشین آلات و دستگاه‌های برقی -1.050241  ...                 0.446128
# 12  ماشین آلات و دستگاه‌های برقی -0.707592  ...                 0.446128
# 13  ماشین آلات و دستگاه‌های برقی  4.295069  ...                 0.446128
# 14  ماشین آلات و دستگاه‌های برقی  0.175439  ...                 0.446128
# 15  ماشین آلات و دستگاه‌های برقی -1.944880  ...                 0.446128
# 16  ماشین آلات و دستگاه‌های برقی -1.193833  ...                 0.446128
# 17  ماشین آلات و دستگاه‌های برقی -2.273808  ...                 0.477273
# 18  ماشین آلات و دستگاه‌های برقی -2.229361  ...                 0.477273
# 19  ماشین آلات و دستگاه‌های برقی -2.558996  ...                 0.455128
# 20  ماشین آلات و دستگاه‌های برقی  4.874310  ...                 0.455128
# 21  ماشین آلات و دستگاه‌های برقی  4.335964  ...                 0.455128
# 22  ماشین آلات و دستگاه‌های برقی  2.801644  ...                 0.455128
# 23  ماشین آلات و دستگاه‌های برقی  2.688953  ...                 0.455128
# 24  ماشین آلات و دستگاه‌های برقی  0.805025  ...                 0.455128
# 25  ماشین آلات و دستگاه‌های برقی -2.887231  ...                 0.455128
# 26  ماشین آلات و دستگاه‌های برقی  0.433761  ...                 0.446581
# 27  ماشین آلات و دستگاه‌های برقی  4.120929  ...                 0.446581
# 28  ماشین آلات و دستگاه‌های برقی  1.780159  ...                 0.446581
# 29  ماشین آلات و دستگاه‌های برقی -2.980132  ...                 0.446581
# 30  ماشین آلات و دستگاه‌های برقی  0.840116  ...                 0.446581
# 31  ماشین آلات و دستگاه‌های برقی -2.820446  ...                 0.446581
# 32  ماشین آلات و دستگاه‌های برقی  0.383997  ...                 0.446581
# 33  ماشین آلات و دستگاه‌های برقی  2.393026  ...                 0.446581
# 34  ماشین آلات و دستگاه‌های برقی -2.397915  ...                 0.446581
# 35  ماشین آلات و دستگاه‌های برقی  0.311554  ...                 0.505902
# 36  ماشین آلات و دستگاه‌های برقی  0.097613  ...                 0.505902
# 37  ماشین آلات و دستگاه‌های برقی  4.671986  ...                 0.505902
# 38  ماشین آلات و دستگاه‌های برقی  4.505802  ...                 0.505902
# 39  ماشین آلات و دستگاه‌های برقی  4.992301  ...                 0.505902
# 40  ماشین آلات و دستگاه‌های برقی  4.778078  ...                 0.505902
# 41  ماشین آلات و دستگاه‌های برقی -0.707234  ...                 0.505902
# 42  ماشین آلات و دستگاه‌های برقی  2.292625  ...                 0.505902
# 43  ماشین آلات و دستگاه‌های برقی  4.997461  ...                 0.505902
# 44  ماشین آلات و دستگاه‌های برقی  4.807958  ...                 0.744048
# 45  ماشین آلات و دستگاه‌های برقی  4.996045  ...                 0.744048
# 46  ماشین آلات و دستگاه‌های برقی  4.067797  ...                 0.744048
# 47  ماشین آلات و دستگاه‌های برقی  4.632646  ...                 0.744048
# 48  ماشین آلات و دستگاه‌های برقی  4.998270  ...                 0.744048
# 49  ماشین آلات و دستگاه‌های برقی  4.996431  ...                 0.744048
#
#     WeeklyPercentile_Rank_y  Weeklysize1  Weeklysize2  WeeklySameSize  \
# 0                  0.772790     0.772790     0.479609       -0.293182
# 1                  0.772790     0.772790     0.479609       -0.293182
# 2                  0.772790     0.772790     0.479609       -0.293182
Mehr = set(df[df.Holder.isin(Mehr)].symbol)

Kosar = ['وکوثر','کوثر']
Kosar = set(df[df.Holder.isin(Kosar)].symbol)

# %%
d = {"Ansar" : Ansar , "Gavam" : Gavam , "Hekmat" : Hekmat , "Mehr" : Mehr , "Kosar" : Kosar}

# %%
len(Hekmat) + len(Ansar) + len(Gavam) + len(Mehr) + len(Kosar)
# Out:
# 34

# %%
len(Ssymbol)
# Out:
# 5

# %%
df[df.jalaliDate == df.jalaliDate.max()]
# Out:
#              date  jalaliDate   symbol      stock_id  \
# 268423   20201104    13990814    بجهرم  3.362926e+16
# 1268862  20201104    13990814     رکیش  2.795297e+16
# 2206770  20201104    13990814  فرابورس  5.874107e+16
# 2469487  20201104    13990814    لپارس  5.187018e+15
# 2760284  20201104    13990814    وامید  5.223239e+16
# 2968299  20201104    13990814    وحکمت  1.277758e+16
# 3156513  20201104    13990814    وغدیر  2.601491e+16
# 3902565  20201104    13990814     کوثر  2.227560e+16
#
#                                        group_name  group_id  \
# 268423                 عرضه برق، گاز، بخاروآب گرم      40.0
# 1268862          رایانه و فعالیت‌های وابسته به آن      72.0
# 2206770       فعالیتهای کمکی به نهادهای مالی واسط      67.0
# 2469487            ساخت دستگاه‌ها و وسایل ارتباطی      32.0
# 2760284                 شرکتهای چند رشته ای صنعتی      39.0
# 2968299  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
# 3156513                 شرکتهای چند رشته ای صنعتی      39.0
# 3902565  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
#
#                                    Holder       nshares        type  Percent  \
# 268423                           بانک سپه  1.352166e+10        bank    56.00
# 1268862                          بانک سپه  2.354439e+08        bank     9.05
# 2206770                 کارگزاری بانک سپه  1.400000e+07      broker     1.00
# 2469487                             وقوام  5.000000e+06        bank     1.66
# 2760284                          بانک سپه  2.107450e+10        bank    70.24
# 2968299                              حکمت  2.988000e+08        bank    19.92
# 3156513                              کوثر  1.446206e+09   insurance     2.00
# 3902565  سرمایه گذاری الماس حکمت ایرانیان  5.396509e+08  investment     8.32
#
#          ...  2-Residual       Ret Holder_id  id      date1 week_of_year  \
# 268423   ...    0.160957  2.194787         0   2 2020-11-04           44
# 1268862  ...   -4.041943 -3.010033         0  12 2020-11-04           44
# 2206770  ...   -2.586499 -4.086869         5  16 2020-11-04           44
# 2469487  ...    2.428788 -2.334206         3  19 2020-11-04           44
# 2760284  ...    2.710391  4.374101         0  22 2020-11-04           44
# 2968299  ...   -1.864138 -0.051038         1  26 2020-11-04           44
# 3156513  ...    2.392745  4.966571         6  28 2020-11-04           44
# 3902565  ...   -5.139241 -4.373710         2  36 2020-11-04           44
#
#          month_of_year  year_of_year     MarketCap  Percentile_Rank
# 268423              11          2020  8.994136e+13            0.625
# 1268862             11          2020  3.016000e+13            0.250
# 2206770             11          2020  1.444352e+14            0.750
# 2469487             11          2020  5.372400e+13            0.375
# 2760284             11          2020  1.088100e+15            1.000
# 2968299             11          2020  8.812500e+12            0.125
# 3156513             11          2020  7.912800e+14            0.875
# 3902565             11          2020  7.812516e+13            0.500
#
# [8 rows x 28 columns]

# %%
df[df.id == 2]
# Out:
#             date  jalaliDate symbol      stock_id                  group_name  \
# 267511  20190928    13980706  بجهرم  3.362926e+16  عرضه برق، گاز، بخاروآب گرم
# 
# 268383          2020  1.109237e+14         0.625000
# 268386          2020  1.145937e+14         0.625000
# 268389          2020  1.093542e+14         0.625000
# 268392          2020  1.046700e+14         0.500000
# 268395          2020  9.950291e+13         0.375000
# 268398          2020  9.803005e+13         0.500000
# 268401          2020  1.008792e+14         0.500000
# 268404          2020  9.638817e+13         0.500000
# 268407          2020  9.320098e+13         0.500000
# 268410          2020  8.974820e+13         0.375000
# 268413          2020  8.907213e+13         0.428571
# 268416          2020  9.295953e+13         0.625000
# 268419          2020  8.967576e+13         0.625000
# 268422          2020  8.800974e+13         0.625000
# 268423          2020  8.994136e+13         0.625000
#
# [263 rows x 28 columns]

# %%
len(set(df.symbol))
# Out:
# 38

# %%
data = pd.DataFrame()
for i in Ssymbol:
    g = df[df.symbol == i]
    print(i)
    for j in d:
#         print(j)
        for k in d[j]:
#             print(k)
            try:
                t = pd.DataFrame()
                S_g = df[df.symbol == k]
                t = FCAPf(S_g,g)
                t['MergedBank'] = j
                data = data.append(t)
            except:
                True
# Out:
# رکیش
# وامید
# وبصادر
# بجهرم
# فرابورس

# %%
len(data)
# Out:
# 15300

# %%
d = data.reset_index(drop = True)

# %%
symbols = list(set(df.symbol))
symbols.sort()
ids = list(range(len(symbols)))
mapingdict = dict(zip(ids,symbols))
d['symbol_x'] = d['id_x'].map(mapingdict)
d['symbol_y'] = d['id_y'].map(mapingdict)

# %%
d[d.symbol_x == 'وبصادر']
# Out:
#            date  jalaliDate  id_x  id_y  week_of_year  month_of_year  \
# 11203  20150325    13940105    24    31            12              3
# 11204  20150328    13940108    24    31            12              3
# 11205  20150329    13940109    24    31            12              3
# 11206  20150330    13940110    24    31            14              3
# 11207  20150331    13940111    24    31            14              3
# 11208  20150404    13940115    24    31            14              4
# 11209  20150405    13940116    24    31            14              4
# 11210  20150406    13940117    24    31            14              4
# 11211  20150407    13940118    24    31            14              4
# 11212  20150408    13940119    24    31            14              4
# 11213  20150411    13940122    24    31            14              4
# 11214  20150412    13940123    24    31            14              4
# 11215  20150413    13940124    24    31            16              4
# 11216  20150414    13940125    24    31            16              4
# 11217  20150415    13940126    24    31            16              4
# 11218  20150418    13940129    24    31            16              4
# 11219  20150419    13940130    24    31            16              4
# 11220  20150420    13940131    24    31            16              4
# 11221  20150421    13940201    24    31            16              4
# 11222  20150422    13940202    24    31            16              4
# 11223  20150425    13940205    24    31            16              4
# 11224  20150426    13940206    24    31            16              4
# 11225  20150427    13940207    24    31            18              4
# 11226  20150428    13940208    24    31            18              4
# 11227  20150429    13940209    24    31            18              4
# 11228  20150503    13940213    24    31            18              5
# 11229  20150505    13940215    24    31            18              5
# 11230  20150506    13940216    24    31            18              5
# 11231  20150509    13940219    24    31            18              5
# 11232  20150510    13940220    24    31            18              5
# ...         ...         ...   ...   ...           ...            ...
# 13261  20151207    13940916    24    13            50             12
# 13262  20151215    13940924    24    13            50             12
# 13263  20151219    13940928    24    13            50             12
# 13264  20151221    13940930    24    13            52             12
# 13265  20151230    13941009    24    13            52             12
# 13266  20160103    13941013    24    13            52              1
# 11227          2015  بانکها و موسسات اعتباری    محصولات کاغذی  0.893855  ...
# 11228          2015  بانکها و موسسات اعتباری    محصولات کاغذی -3.543743  ...
# 11229          2015  بانکها و موسسات اعتباری    محصولات کاغذی  0.000000  ...
# 11230          2015  بانکها و موسسات اعتباری    محصولات کاغذی -0.357143  ...
# 11231          2015  بانکها و موسسات اعتباری    محصولات کاغذی -3.464755  ...
# 11232          2015  بانکها و موسسات اعتباری    محصولات کاغذی -1.485149  ...
# ...             ...                      ...              ...       ...  ...
# 13261          2015  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.000000  ...
# 13262          2015  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.232019  ...
# 13263          2015  بانکها و موسسات اعتباری  سیمان، آهک و گچ -0.805524  ...
# 13264          2015  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.000000  ...
# 13265          2015  بانکها و موسسات اعتباری  سیمان، آهک و گچ  1.960784  ...
# 13266          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.000000  ...
# 13267          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.000000  ...
# 13268          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.684932  ...
# 13269          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  3.401361  ...
# 13270          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -0.219298  ...
# 13271          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -0.549451  ...
# 13272          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  1.878453  ...
# 13273          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.867679  ...
# 13274          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  2.043011  ...
# 13275          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  1.896733  ...
# 13276          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -3.102378  ...
# 13277          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -2.774813  ...
# 13278          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  1.097695  ...
# 13279          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -0.542888  ...
# 13280          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  3.930131  ...
# 13281          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  4.516807  ...
# 13282          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -2.010050  ...
# 13283          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  2.051282  ...
# 13284          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  3.115578  ...
# 13285          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  2.729045  ...
# 13286          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -4.459203  ...
# 13287          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ  0.993049  ...
# 13288          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -1.278269  ...
# 13289          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -2.290837  ...
# 13290          2016  بانکها و موسسات اعتباری  سیمان، آهک و گچ -0.203874  ...
#
#        Weeklysize2  WeeklySameSize  WeeklyFCAPf  WeeklyFCA  Weeklyρ_2_f  \
# 11203     0.294444       -0.481481     0.013462   0.013517     0.915461
# 11204     0.294444       -0.481481     0.013462   0.013517     0.915461
# 11205     0.294444       -0.481481     0.013462   0.013517     0.223932
# 11206     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11207     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11208     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11209     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11210     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11211     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11212     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11213     0.294613       -0.508979     0.012958   0.013042     0.223932
# 11214     0.294613       -0.508979     0.012958   0.013042    -0.286873
# 11215     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11216     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11217     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11218     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11219     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11220     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11221     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11222     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11223     0.252323       -0.544646     0.011952   0.012098    -0.286873
# 11224     0.252323       -0.544646     0.011952   0.012098    -0.048536
# 11225     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11226     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11227     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11228     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11229     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11230     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11231     0.265341       -0.570265     0.011954   0.012110    -0.048536
# 11232     0.265341       -0.570265     0.011954   0.012110     0.618255
# ...            ...             ...          ...        ...          ...
# 13261     0.300366       -0.624542     0.011926   0.011868     0.132201
# 13262     0.300366       -0.624542     0.011926   0.011868     0.132201
# 13263     0.300366       -0.624542     0.011926   0.011868    -1.000000
# 13264     0.309524       -0.654762     0.011926   0.011868    -1.000000
# 13265     0.309524       -0.654762     0.011926   0.011868          NaN
# 13266     0.307692       -0.615385     0.011926   0.011868    -0.179988
# 13267     0.307692       -0.615385     0.011926   0.011869    -0.179988
# 13268     0.307692       -0.615385     0.011926   0.011869    -0.179988
# 13269     0.307692       -0.615385     0.011926   0.011869    -0.179988
# 13270     0.307692       -0.615385     0.011926   0.011869    -0.179988
# 13271     0.307692       -0.615385     0.011926   0.011869     0.541539
# 13272     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13273     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13274     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13275     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13276     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13277     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13278     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13279     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13280     0.231136       -0.723260     0.011838   0.011791     0.541539
# 13281     0.231136       -0.723260     0.011838   0.011791     0.098879
# 13282     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13283     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13284     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13285     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13286     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13287     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13288     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13289     0.205535       -0.769333     0.010397   0.010504     0.098879
# 13290     0.205535       -0.769333     0.010397   0.010504          NaN
#
#        Weeklyρ_4_f  Weeklyρ_5_f  MergedBank  symbol_x  symbol_y
# 11203     0.965023     0.955549       Ansar    وبصادر     چکاوه
# 11204     0.965023     0.955549       Ansar    وبصادر     چکاوه
# 11205    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11206    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11207    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11208    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11209    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11210    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11211    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11212    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11213    -0.104874    -0.018361       Ansar    وبصادر     چکاوه
# 11214    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11215    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11216    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11217    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11218    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11219    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11220    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11221    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11222    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11223    -0.007254    -0.292891       Ansar    وبصادر     چکاوه
# 11224     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11225     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11226     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11227     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11228     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11229     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11230     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11231     0.364296     0.053513       Ansar    وبصادر     چکاوه
# 11232     0.064059     0.549994       Ansar    وبصادر     چکاوه
# ...            ...          ...         ...       ...       ...
# 13261    -0.001189     0.075148        Mehr    وبصادر     سهگمت
# 13262    -0.001189     0.075148        Mehr    وبصادر     سهگمت
# 13263     1.000000    -1.000000        Mehr    وبصادر     سهگمت
# 13264     1.000000    -1.000000        Mehr    وبصادر     سهگمت
# 13265          NaN          NaN        Mehr    وبصادر     سهگمت
# 13266    -0.485423    -0.354407        Mehr    وبصادر     سهگمت
# 13267    -0.485423    -0.354407        Mehr    وبصادر     سهگمت
# 13268    -0.485423    -0.354407        Mehr    وبصادر     سهگمت
# 13269    -0.485423    -0.354407        Mehr    وبصادر     سهگمت
# 13270    -0.485423    -0.354407        Mehr    وبصادر     سهگمت
# 13271     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13272     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13273     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13274     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13275     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13276     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13277     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13278     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13279     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13280     0.365075     0.474878        Mehr    وبصادر     سهگمت
# 13281    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13282    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13283    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13284    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13285    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13286    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13287    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13288    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13289    -0.151392     0.167546        Mehr    وبصادر     سهگمت
# 13290          NaN          NaN        Mehr    وبصادر     سهگمت
#
# [2088 rows x 63 columns]

# %%
def add(row):
    if len(row)<2:
        row = '0'+ row
    return row
d['month_of_year'] = d['month_of_year'].astype(str).apply(add )
d['week_of_year'] = d['week_of_year'].astype(str).apply(add )


d['year_of_year'] = d['year_of_year'].astype(str)

d['Year_Month_week'] = d['year_of_year'] + d['month_of_year'] + d['week_of_year']
d['Year_Month'] = d['year_of_year'] + d['month_of_year']

days = list(set(d.date))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t'] = d['date'].map(mapingdict)

days = list(set(d.Year_Month_week))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t_Week'] = d['Year_Month_week'].map(mapingdict)

days = list(set(d.Year_Month))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t_Month'] = d['Year_Month'].map(mapingdict)


d['id'] = d['symbol_x'] + d['symbol_y']
ids = list(set(d.id))
ids.sort()
id = list(range(len(ids)))
mapingdict = dict(zip(ids, id))
d['id'] = d['id'].map(mapingdict)

def NormalTransform(df_sub):
    col = df_sub.transform('rank')
    return (col-col.mean())/col.std()


gg = d.groupby(['t'])
d['FCAP*'] = gg['FCAPf'].apply(NormalTransform)
d['FCA*'] = gg['FCA'].apply(NormalTransform)

gg = d.groupby(['t_Week'])
d['WeeklyFCAP*'] = gg['WeeklyFCAPf'].apply(NormalTransform)
d['WeeklyFCA*'] = gg['WeeklyFCA'].apply(NormalTransform)

gg = d.groupby(['t_Month'])
d['MonthlyFCAP*'] = gg['MonthlyFCAPf'].apply(NormalTransform) 
d['MonthlyFCA*'] = gg['MonthlyFCA'].apply(NormalTransform)

# %%
d['EventDay'] = np.nan
d["jalaliDate"] = d["jalaliDate"].astype(int)
d[(d.jalaliDate >= 13990312)&(d.MergedBank == 'Mehr')]
d[(d.jalaliDate >= 13990906)&(d.MergedBank == 'Kosar')]
d.loc[(d.MergedBank == 'Hekmat'),'EventDay'] = d.loc[(d.jalaliDate == 13990311)&(d.MergedBank == 'Hekmat')].t.iloc[0]
d['Period'] = d['t'] - d['EventDay']

# %%
d.jalaliDate.min()
# Out:
# 13940105

# %%
d[(d.jalaliDate == 13971214)]
# Out:
#            date  jalaliDate  id_x  id_y week_of_year month_of_year  \
# 98     20190305    13971214    12    19           10            03
# 449    20190305    13971214    12    25           10            03
# 468    20190305    13971214    12    36           10            03
# 1079   20190305    13971214    12    28           10            03
# 1456   20190305    13971214    12    34           10            03
# 1480   20190305    13971214    12     7           10            03
# 2526   20190305    13971214    22    19           10            03
# 3355   20190305    13971214    22    25           10            03
# 7292   20190305    13971214    22    36           10            03
# 10286  20190305    13971214    22    28           10            03
# 10669  20190305    13971214    22    34           10            03
# 11177  20190305    13971214    22     7           10            03
#
#       year_of_year                      group_name_x  \
# 98            2019  رایانه و فعالیت‌های وابسته به آن
# 449           2019  رایانه و فعالیت‌های وابسته به آن
# 468           2019  رایانه و فعالیت‌های وابسته به آن
# 1079          2019  رایانه و فعالیت‌های وابسته به آن
# 1456          2019  رایانه و فعالیت‌های وابسته به آن
# 1480          2019  رایانه و فعالیت‌های وابسته به آن
# 2526          2019         شرکتهای چند رشته ای صنعتی
# 3355          2019         شرکتهای چند رشته ای صنعتی
# 7292          2019         شرکتهای چند رشته ای صنعتی
# 10286         2019         شرکتهای چند رشته ای صنعتی
# 10669         2019         شرکتهای چند رشته ای صنعتی
# 11177         2019         شرکتهای چند رشته ای صنعتی
#
#                                    group_name_y    Ret_x  ...  t_Month  id  \
# 98               ساخت دستگاه‌ها و وسایل ارتباطی -0.52356  ...       48   7
# 449                   واسطه‌گری‌های مالی و پولی -0.52356  ...       48   8
# 468    بیمه وصندوق بازنشستگی به جزتامین اجتماعی -0.52356  ...       48  13
# 1079                  شرکتهای چند رشته ای صنعتی -0.52356  ...       48  10
# 1456                  سایر محصولات کانی غیرفلزی -0.52356  ...       48  12
# 1480             حمل ونقل، انبارداری و ارتباطات -0.52356  ...       48   6
# 2526             ساخت دستگاه‌ها و وسایل ارتباطی -3.38590  ...       48  35
# 3355                  واسطه‌گری‌های مالی و پولی -3.38590  ...       48  39
# 7292   بیمه وصندوق بازنشستگی به جزتامین اجتماعی -3.38590  ...       48  50
# 10286                 شرکتهای چند رشته ای صنعتی -3.38590  ...       48  42
# 10669                 سایر محصولات کانی غیرفلزی -3.38590  ...       48  48
# 11177            حمل ونقل، انبارداری و ارتباطات -3.38590  ...       48  25
#
#           FCAP*      FCA*  WeeklyFCAP*  WeeklyFCA*  MonthlyFCAP*  MonthlyFCA*  \
# 98    -0.693375 -0.693375    -1.034077   -1.232938     -0.660609    -0.660609
# 449   -0.970725 -0.970725    -1.232938   -1.034077     -0.899162    -0.899162
# 468   -0.138675 -0.138675    -0.636355   -0.636355     -0.422056    -0.422056
# 1079  -0.416025 -0.416025    -0.835216   -0.835216     -1.376269    -1.137716
# 1456  -1.525426 -1.525426    -1.431799   -1.630660     -1.137716    -1.376269
# 1480  -1.248075 -1.248075    -1.630660   -1.431799     -1.614822    -1.614822
# 2526   0.970725  0.970725     0.735786    0.735786      0.862462     0.862462
# 3355   1.248075  1.525426     1.133508    1.531229      1.211117     1.559771
# 7292   0.416025  0.416025    -0.059658   -0.059658      0.165152     0.165152
# 10286  0.138675  0.138675    -0.397722   -0.397722     -0.155977    -0.155977
# 10669  1.525426  1.248075     1.531229    1.133508      1.559771     1.211117
# 11177  0.693375  0.693375     0.338064    0.338064      0.513807     0.513807
#
#        EventDay  Period
# 98          NaN     NaN
# 449         NaN     NaN
# 468      1224.0  -293.0
# 1079        NaN     NaN
# 1456        NaN     NaN
# 1480        NaN     NaN
# 2526        NaN     NaN
# 3355        NaN     NaN
# 7292     1224.0  -293.0
# 10286       NaN     NaN
# 10669       NaN     NaN
# 11177       NaN     NaN
#
# [12 rows x 77 columns]

# %%
d = d[~d.Period.isnull()]

# %%
d = d[d.Period > -2 * d.Period.max()]

# %%
set(d.id)
# Out:
# {2, 4, 9, 13, 16, 18, 40, 50}

# %%
d.head().columns
n3 = path + 'SepahNormalzedFCAP1.0.csv'
d.to_csv(n3,index = False)
print('d done')
a = d.drop_duplicates(['t','id'])
n3 = path + 'SepahNormalzedFCAP1.1.csv'
a.to_csv(n3,index = False)

Montly =  a.drop_duplicates(['id','t_Month'],keep = "last")
n3 = path + 'SepahMonthlyNormalzedFCAP1.1.csv'
Montly.to_csv(n3,index = False)

n3 = path + 'SepahWeeklyNormalzedFCAP1.1.csv'
Weekly = a.drop_duplicates(['id','t_Week'],keep = "last")
Weekly.to_csv(n3,index = False)
# Out:
# d done

# %%
path
# Out:
# 'H:\\Economics\\Finance(Prof.Heidari-Aghajanzadeh)\\Data\\\\'
