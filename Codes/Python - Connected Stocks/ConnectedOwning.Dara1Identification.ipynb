# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib as plt
import re as ree
import requests
import csv
import datetime
import time
import random

# %%
def vv4(row):
    row = str(row)
    X = [1,1,1]
    X[0] = row[0:4]
    X[1] = row[4:6]
    X[2] = row[6:8]
    return X[0]+'-'+X[1]+'-'+X[2]

def vv(row):
    X = row.split('-')
    return X[0]+X[1]+X[2]

def DriveYearMonthDay(d):
    d['jalaliDate'] = d['jalaliDate'].astype(str)
    d['Year'] = d['jalaliDate'].str[0:4]
    d['Month'] = d['jalaliDate'].str[4:6]
    d['Day'] = d['jalaliDate'].str[6:8]
    d['jalaliDate'] = d['jalaliDate'].astype(int)
    return d

def convert_ar_characters(input_str):

    mapping = {
        'ك': 'ک',
        'گ':'گ',
        'دِ': 'د',
        'بِ': 'ب',
        'زِ': 'ز',
        'ذِ': 'ذ',
        'شِ': 'ش',
        'سِ': 'س',
        'ى': 'ی',
        'ي': 'ی'
    }
    return _multiple_replace(mapping, input_str)


def _multiple_replace(mapping, text):
    pattern = "|".join(map(ree.escape, mapping.keys()))
    return ree.sub(pattern, lambda m: mapping[m.group()], str(text))
def vv2(row):
    X = row.split('/')
    return X[0]+X[1]+X[2]
def vv3(row):
    X = row.split('/')
    if len(X[0])<4:
        X[0] = '13' + X[0]
    if len(X[1])<2:
        X[1] = '0'+X[1]
    if len(X[2])<2:
        X[2] = '0'+X[2]
    return X[0]+X[1]+X[2]

# %%
path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data\\"

# %%
# path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data"

n = path + 'Cleaned_Stocks_Holders_1399-09-12_From94.csv'
df = pd.read_csv(n)

df = df.drop(df.loc[df['Holder']=='شخص حقیقی'].index)
df = df.drop(df[(df['Trade']=='No')&((df['close_price']==10)|(df['close_price']==1000)|(df['close_price']==10000)|(df['close_price']==100000))].index)
df = df.drop(df[(df['symbol'] == 'وقوام')&(df['close_price'] == 1000)].index)
symbols = [ 'سپرده','هما','وهنر-پذیره','نکالا','تکالا','اکالا','توسعه گردشگری ','وآفر','ودانا','نشار','نبورس','چبسپا','بدکو','چکارم','تراک','کباده','فبستم','تولیددارو','قیستو','خلیبل','پشاهن','قاروم','هوایی سامان','کورز','شلیا','دتهران','نگین','کایتا','غیوان','تفیرو','سپرمی','بتک']
df = df.drop(df[df['symbol'].isin(symbols)].index)
df = df.drop(df[df.group_name== 'صندوق سرمایه گذاری قابل معامله'].index)
df = df.drop(df[(df.symbol == 'اتکای')&(df.close_price == 1000)].index)

# %%
mlist = ['سرمایه گذاری واسطه گری مالی یکم',]

# %%
mlist = set(df[df.Holder.str.contains("مالی یکم")].symbol)

# %%
HolderData = df

# %%
HolderData
# Out:
#              date  jalaliDate symbol      stock_id  \
# 2420     20150325    13940105  آ س پ  1.761747e+16
# 2421     20150325    13940105  آ س پ  1.761747e+16
# 2422     20150325    13940105  آ س پ  1.761747e+16
# 2423     20150325    13940105  آ س پ  1.761747e+16
# 2424     20150325    13940105  آ س پ  1.761747e+16
# 2425     20150328    13940108  آ س پ  1.761747e+16
# 2426     20150328    13940108  آ س پ  1.761747e+16
# 2427     20150328    13940108  آ س پ  1.761747e+16
# 2428     20150328    13940108  آ س پ  1.761747e+16
# 2429     20150328    13940108  آ س پ  1.761747e+16
# 2430     20150329    13940109  آ س پ  1.761747e+16
# 2431     20150329    13940109  آ س پ  1.761747e+16
# 2432     20150329    13940109  آ س پ  1.761747e+16
# 2433     20150329    13940109  آ س پ  1.761747e+16
# 2434     20150329    13940109  آ س پ  1.761747e+16
# 2435     20150330    13940110  آ س پ  1.761747e+16
# 2436     20150330    13940110  آ س پ  1.761747e+16
# 2437     20150330    13940110  آ س پ  1.761747e+16
# 2438     20150330    13940110  آ س پ  1.761747e+16
# 2439     20150330    13940110  آ س پ  1.761747e+16
# 2440     20150331    13940111  آ س پ  1.761747e+16
# 2441     20150331    13940111  آ س پ  1.761747e+16
# 2442     20150331    13940111  آ س پ  1.761747e+16
# 2443     20150331    13940111  آ س پ  1.761747e+16
# 2444     20150331    13940111  آ س پ  1.761747e+16
# 2445     20150404    13940115  آ س پ  1.761747e+16
# 2446     20150404    13940115  آ س پ  1.761747e+16
# 2447     20150404    13940115  آ س پ  1.761747e+16
# 2448     20150404    13940115  آ س پ  1.761747e+16
# 2449     20150404    13940115  آ س پ  1.761747e+16
# ...           ...         ...    ...           ...
# 4003041  20200921    13990631   گکیش  4.466576e+16
# 4003043  20200922    13990701   گکیش  4.466576e+16
# 4003045  20200923    13990702   گکیش  4.466576e+16
# 4003047  20200926    13990705   گکیش  4.466576e+16
# 4003049  20200927    13990706   گکیش  4.466576e+16
# 4003051  20200928    13990707   گکیش  4.466576e+16
# 4003053  20200929    13990708   گکیش  4.466576e+16
# 4003055  20200930    13990709   گکیش  4.466576e+16
# 4003057  20201003    13990712   گکیش  4.466576e+16
# 4003059  20201004    13990713   گکیش  4.466576e+16
# 4003061  20201005    13990714   گکیش  4.466576e+16
# 4003063  20201006    13990715   گکیش  4.466576e+16
# 4003065  20201007    13990716   گکیش  4.466576e+16
# 4003067  20201010    13990719   گکیش  4.466576e+16
# 4003069  20201011    13990720   گکیش  4.466576e+16
# 4003071  20201012    13990721   گکیش  4.466576e+16
# 4003073  20201013    13990722   گکیش  4.466576e+16
# 4003075  20201014    13990723   گکیش  4.466576e+16
# 4003077  20201018    13990727   گکیش  4.466576e+16
# 4003079  20201019    13990728   گکیش  4.466576e+16
# 4003081  20201020    13990729   گکیش  4.466576e+16
# 4003083  20201021    13990730   گکیش  4.466576e+16
# 4003085  20201024    13990803   گکیش  4.466576e+16
# 4003087  20201026    13990805   گکیش  4.466576e+16
# 4003089  20201027    13990806   گکیش  4.466576e+16
# 4003091  20201028    13990807   گکیش  4.466576e+16
# 4003093  20201031    13990810   گکیش  4.466576e+16
# 4003095  20201101    13990811   گکیش  4.466576e+16
# 4003097  20201102    13990812   گکیش  4.466576e+16
# 4003099  20201104    13990814   گکیش  4.466576e+16
#
#                           group_name  group_id  \
# 2420     انبوه سازی، املاک و مستغلات      70.0
# 2421     انبوه سازی، املاک و مستغلات      70.0
# 2422     انبوه سازی، املاک و مستغلات      70.0
# 2423     انبوه سازی، املاک و مستغلات      70.0
# 2424     انبوه سازی، املاک و مستغلات      70.0
# 2425     انبوه سازی، املاک و مستغلات      70.0
# 2426     انبوه سازی، املاک و مستغلات      70.0
# 2427     انبوه سازی، املاک و مستغلات      70.0
# 2428     انبوه سازی، املاک و مستغلات      70.0
# 2429     انبوه سازی، املاک و مستغلات      70.0
# 2430     انبوه سازی، املاک و مستغلات      70.0
# 2431     انبوه سازی، املاک و مستغلات      70.0
# 2432     انبوه سازی، املاک و مستغلات      70.0
# 2433     انبوه سازی، املاک و مستغلات      70.0
# 2434     انبوه سازی، املاک و مستغلات      70.0
# 2435     انبوه سازی، املاک و مستغلات      70.0
# 2436     انبوه سازی، املاک و مستغلات      70.0
# 2437     انبوه سازی، املاک و مستغلات      70.0
# 2438     انبوه سازی، املاک و مستغلات      70.0
# 2439     انبوه سازی، املاک و مستغلات      70.0
# 2440     انبوه سازی، املاک و مستغلات      70.0
# 2441     انبوه سازی، املاک و مستغلات      70.0
# 2442     انبوه سازی، املاک و مستغلات      70.0
# 2443     انبوه سازی، املاک و مستغلات      70.0
# 2444     انبوه سازی، املاک و مستغلات      70.0
# 2445     انبوه سازی، املاک و مستغلات      70.0
# 2446     انبوه سازی، املاک و مستغلات      70.0
# 2447     انبوه سازی، املاک و مستغلات      70.0
# 2448     انبوه سازی، املاک و مستغلات      70.0
# 2449     انبوه سازی، املاک و مستغلات      70.0
# ...                              ...       ...
# 4003041                هتل و رستوران      55.0
# 4003043                هتل و رستوران      55.0
# 4003045                هتل و رستوران      55.0
# 4003047                هتل و رستوران      55.0
# 4003049                هتل و رستوران      55.0
# 4003051                هتل و رستوران      55.0
# 4003053                هتل و رستوران      55.0
# 4003055                هتل و رستوران      55.0
# 4003057                هتل و رستوران      55.0
# 4003059                هتل و رستوران      55.0
# 4003061                هتل و رستوران      55.0
# 4003063                هتل و رستوران      55.0
# 4003065                هتل و رستوران      55.0
# 4003067                هتل و رستوران      55.0
# 4003069                هتل و رستوران      55.0
# 4003071                هتل و رستوران      55.0
# 4003073                هتل و رستوران      55.0
# 4003075                هتل و رستوران      55.0
# 4003077                هتل و رستوران      55.0
# 4003079                هتل و رستوران      55.0
# 4003081                هتل و رستوران      55.0
# 4003083                هتل و رستوران      55.0
# 4003085                هتل و رستوران      55.0
# 4003087                هتل و رستوران      55.0
# 4003089                هتل و رستوران      55.0
# 4003091                هتل و رستوران      55.0
# 4003093                هتل و رستوران      55.0
# 4003095                هتل و رستوران      55.0
# 4003097                هتل و رستوران      55.0
# 4003099                هتل و رستوران      55.0
#
#                                        Holder      nshares        type  \
# 2420     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2421                                    وغدیر   67896459.0  investment
# 2422                            ایرانیان اطلس  121316125.0     private
# 2423                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2424                                     ثاخت  321682470.0     private
# 2425     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2426                                    وغدیر   67896459.0  investment
# 2427                            ایرانیان اطلس  121015422.0     private
# 2428                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2429                                     ثاخت  321682470.0     private
# 2430     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2431                                    وغدیر   67896459.0  investment
# 2432                            ایرانیان اطلس  121015422.0     private
# 2433                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2434                                     ثاخت  321682470.0     private
# 2435     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2436                                    وغدیر   67896459.0  investment
# 2437                            ایرانیان اطلس  121015422.0     private
# 2438                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2439                                     ثاخت  321682470.0     private
# 2440     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2441                                    وغدیر   67896459.0  investment
# 2442                            ایرانیان اطلس  121015422.0     private
# 2443                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2444                                     ثاخت  321682470.0     private
# 2445     صندوق بیمه اجتماعی روستاییان و عشایر   38798288.0   insurance
# 2446                                    وغدیر   67896459.0  investment
# 2447                            ایرانیان اطلس  121015422.0     private
# 2448                    صنعتی و بازرگانی غدیر  164077508.0     private
# 2449                                     ثاخت  321682470.0     private
# ...                                       ...          ...         ...
# 4003041               کارآفرین ستاره بهارستان    1085103.0        None
# 4003043               کارآفرین ستاره بهارستان    1085103.0        None
# 4003045               کارآفرین ستاره بهارستان    1085103.0        None
# 4003047               کارآفرین ستاره بهارستان    1085103.0        None
# 4003049               کارآفرین ستاره بهارستان    1085103.0        None
# 4003051               کارآفرین ستاره بهارستان    1085103.0        None
# 4003053               کارآفرین ستاره بهارستان    1085103.0        None
# 4003055               کارآفرین ستاره بهارستان    1085103.0        None
# 4003057               کارآفرین ستاره بهارستان    1085103.0        None
# 4003059               کارآفرین ستاره بهارستان    1085103.0        None
# 4003061               کارآفرین ستاره بهارستان    1085103.0        None
# 4003063               کارآفرین ستاره بهارستان    1085103.0        None
# 4003065               کارآفرین ستاره بهارستان    1085103.0        None
# 4003067               کارآفرین ستاره بهارستان    1085103.0        None
# 4003069               کارآفرین ستاره بهارستان    1085103.0        None
# 4003071               کارآفرین ستاره بهارستان    1085103.0        None
# 4003073               کارآفرین ستاره بهارستان    1085103.0        None
# 4003075               کارآفرین ستاره بهارستان    1085103.0        None
# 4003077               کارآفرین ستاره بهارستان    1085103.0        None
# 4003079               کارآفرین ستاره بهارستان    1085103.0        None
# 4003081               کارآفرین ستاره بهارستان    1085103.0        None
# 4003083               کارآفرین ستاره بهارستان    1085103.0        None
# 4003085               کارآفرین ستاره بهارستان    1085103.0        None
# 4003087               کارآفرین ستاره بهارستان    1085103.0        None
# 4003089               کارآفرین ستاره بهارستان    1085103.0        None
# 4003091               کارآفرین ستاره بهارستان    1085103.0        None
# 4003093               کارآفرین ستاره بهارستان    1085103.0        None
# 4003095               کارآفرین ستاره بهارستان    1085103.0        None
# 4003097               کارآفرین ستاره بهارستان    1085103.0        None
# 4003099               کارآفرین ستاره بهارستان    1085103.0        None
#
#          Percent       shrout  close_price Number_Change  \
# 2420        4.84  800000000.0       1261.0             -
# 2421        8.48  800000000.0       1261.0             -
# 2422       15.16  800000000.0       1261.0             -
# 2423       20.50  800000000.0       1261.0             -
# 2424       40.21  800000000.0       1261.0             -
# 2425        4.84  800000000.0       1276.0           0.0
# 2426        8.48  800000000.0       1276.0           0.0
# 2427       15.12  800000000.0       1276.0     -300703.0
# 2428       20.50  800000000.0       1276.0           0.0
# 2429       40.21  800000000.0       1276.0           0.0
# 2430        4.84  800000000.0       1335.0           0.0
# 2431        8.48  800000000.0       1335.0           0.0
# 2432       15.12  800000000.0       1335.0           0.0
# 2433       20.50  800000000.0       1335.0           0.0
# 2434       40.21  800000000.0       1335.0           0.0
# 2435        4.84  800000000.0       1310.0           0.0
# 2436        8.48  800000000.0       1310.0           0.0
# 2437       15.12  800000000.0       1310.0           0.0
# 2438       20.50  800000000.0       1310.0           0.0
# 2439       40.21  800000000.0       1310.0           0.0
# 2440        4.84  800000000.0       1306.0           0.0
# 2441        8.48  800000000.0       1306.0           0.0
# 2442       15.12  800000000.0       1306.0           0.0
# 2443       20.50  800000000.0       1306.0           0.0
# 2444       40.21  800000000.0       1306.0           0.0
# 2445        4.84  800000000.0       1371.0           0.0
# 2446        8.48  800000000.0       1371.0           0.0
# 2447       15.12  800000000.0       1371.0           0.0
# 2448       20.50  800000000.0       1371.0           0.0
# 2449       40.21  800000000.0       1371.0           0.0
# ...          ...          ...          ...           ...
# 4003041     1.69  128000000.0      72866.0           0.0
# 4003043     1.69  128000000.0      72866.0           0.0
# 4003045     1.69  128000000.0      72866.0           0.0
# 4003047     1.69  128000000.0      72866.0           0.0
# 4003049     1.69  128000000.0      72866.0           0.0
# 4003051     1.69  128000000.0      72866.0           0.0
# 4003053     1.69  128000000.0      72849.0           0.0
# 4003055     1.69  128000000.0      72843.0           0.0
# 4003057     1.69  128000000.0      72841.0           0.0
# 4003059     1.69  128000000.0      72834.0           0.0
# 4003061     1.69  128000000.0      72833.0           0.0
# 4003063     1.69  128000000.0      72833.0           0.0
# 4003065     1.69  128000000.0      72822.0           0.0
# 4003067     1.69  128000000.0      72800.0           0.0
# 4003069     1.69  128000000.0      72750.0           0.0
# 4003071     1.69  128000000.0      72712.0           0.0
# 4003073     1.69  128000000.0      72692.0           0.0
# 4003075     1.69  128000000.0      72685.0           0.0
# 4003077     1.69  128000000.0      72668.0           0.0
# 4003079     1.69  128000000.0      72659.0           0.0
# 4003081     1.69  128000000.0      72659.0           0.0
# 4003083     1.69  128000000.0      72643.0           0.0
# 4003085     1.69  128000000.0      72638.0           0.0
# 4003087     1.69  128000000.0      72636.0           0.0
# 4003089     1.69  128000000.0      72607.0           0.0
# 4003091     1.69  128000000.0      72601.0           0.0
# 4003093     1.69  128000000.0      72476.0           0.0
# 4003095     1.69  128000000.0      72318.0           0.0
# 4003097     1.69  128000000.0      72304.0           0.0
# 4003099     1.69  128000000.0      72240.0           0.0
#
#                 Percent_Change Condition Trade
# 2420                         -   Orginal   Yes
# 2421                         -   Orginal   Yes
# 2422                         -   Orginal   Yes
# 2423                         -   Orginal   Yes
# 2424                         -   Orginal   Yes
# 2425                       0.0   Orginal   Yes
# 2426                       0.0   Orginal   Yes
# 2427     -0.040000000000000924   Orginal   Yes
# 2428                       0.0   Orginal   Yes
# 2429                       0.0   Orginal   Yes
# 2430                       0.0   Orginal   Yes
# 2431                       0.0   Orginal   Yes
# 2432                       0.0   Orginal   Yes
# 2433                       0.0   Orginal   Yes
# 2434                       0.0   Orginal   Yes
# 2435                       0.0   Orginal   Yes
# 2436                       0.0   Orginal   Yes
# 2437                       0.0   Orginal   Yes
# 2438                       0.0   Orginal   Yes
# 2439                       0.0   Orginal   Yes
# 2440                       0.0   Orginal   Yes
# 2441                       0.0   Orginal   Yes
# 2442                       0.0   Orginal   Yes
# 2443                       0.0   Orginal   Yes
# 2444                       0.0   Orginal   Yes
# 2445                       0.0   Orginal   Yes
# 2446                       0.0   Orginal   Yes
# 2447                       0.0   Orginal   Yes
# 2448                       0.0   Orginal   Yes
# 2449                       0.0   Orginal   Yes
# ...                        ...       ...   ...
# 4003041                    0.0   Orginal    No
# 4003043                    0.0   Orginal    No
# 4003045                    0.0   Orginal    No
# 4003047                    0.0   Orginal    No
# 4003049                    0.0   Orginal    No
# 4003051                    0.0   Orginal    No
# 4003053                    0.0   Orginal   Yes
# 4003055                    0.0   Orginal   Yes
# 4003057                    0.0   Orginal   Yes
# 4003059                    0.0   Orginal   Yes
# 4003061                    0.0   Orginal   Yes
# 4003063                    0.0   Orginal    No
# 4003065                    0.0   Orginal   Yes
# 4003067                    0.0   Orginal   Yes
# 4003069                    0.0   Orginal   Yes
# 4003071                    0.0   Orginal   Yes
# 4003073                    0.0   Orginal   Yes
# 4003075                    0.0   Orginal   Yes
# 4003077                    0.0   Orginal   Yes
# 4003079                    0.0   Orginal   Yes
# 4003081                    0.0   Orginal    No
# 4003083                    0.0   Orginal   Yes
# 4003085                    0.0   Orginal   Yes
# 4003087                    0.0   Orginal   Yes
# 4003089                    0.0   Orginal   Yes
# 4003091                    0.0   Orginal   Yes
# 4003093                    0.0   Orginal   Yes
# 4003095                    0.0   Orginal   Yes
# 4003097                    0.0   Orginal   Yes
# 4003099                    0.0   Orginal   Yes
#
# [3132149 rows x 16 columns]

# %%
# mlist1 = ["کارگزاری بانک سپه", 'بانک سپه']
# Ssymbol = set(df[(df.Holder.isin(mlist1))].symbol)
# mlist2 = ['کارگزاری بانک انصار',
# 'تعاونی مصرف کارکنان بانک انصار',
# 'وقوام','حکمت',
#  'صندوق سرمایه گذاری کارکنان حکمت',
# 'سرمایه گذاری مهر اقتصاد ایرانیان',
# 'گروه مالی مهر اقتصاد',
# 'وکوثر','کوثر',
# 'سرمایه گذاری الماس حکمت ایرانیان']
# Osymbol = set(df[(df.Holder.isin(mlist2))].symbol)

# %%
# path = r"H:\Economics\Finance(Prof.Heidari-Aghajanzadeh)\Data"

n1 = path + 'Stocks_Prices_1399-09-12' + '.csv'
df1 = pd.read_csv(n1)

df1['jalaliDate'] = df1['jalaliDate'].apply(vv)
df = df1
symbols = [ 'سپرده','هما','وهنر-پذيره','نکالا','تکالا','اکالا','توسعه گردشگری ','وآفر','ودانا','نشار','نبورس','چبسپا','بدکو','چکارم','تراک','کباده','فبستم','تولیددارو','قیستو','خلیبل','پشاهن','قاروم','هوایی سامان','کورز','شلیا','دتهران','نگین','کایتا','غیوان','تفیرو','سپرمی','بتک']
df = df.drop(df[df['name'].isin(symbols)].index)
df = df.drop(df[df.group_name== 'صندوق سرمایه گذاری قابل معامله'].index)

df['name'] = df['name'].apply(lambda x: convert_ar_characters(x))
slist = set(HolderData.symbol)

df = df[df.name.isin(slist)]
df = df.drop_duplicates()
df = df.drop(df.loc[(df['volume'] == 0)].index).sort_values(by =['name','jalaliDate']).drop(columns = ['volume','quantity']).rename(columns = {'name':'symbol'})
df = DriveYearMonthDay(df)

PriceData = pd.DataFrame()
PriceData = PriceData.append(df[['jalaliDate', 'date', 'symbol','close_price','group_id']])
PriceData['date1'] = PriceData['date'].apply(vv4)
PriceData['date1'] = pd.to_datetime(PriceData['date1']) 
PriceData['week_of_year'] = PriceData['date1'].dt.week 
PriceData['year_of_year'] = PriceData['date1'].dt.year
gg =PriceData.groupby('symbol')
PriceData['Ret'] = gg['close_price'].pct_change(periods = 1)*100
PriceData.head()
n = path + 'Factors-Daily.xlsx'
Factors = pd.read_excel(n)
PriceData = PriceData.merge(Factors,on = ['jalaliDate','date']).sort_values(by =['symbol','date']).reset_index(drop=True).dropna()

# %%
n = path + 'RiskFree.xlsx'
df3 = pd.read_excel(n)
df3 = df3.rename(columns = {'Unnamed: 2' : 'Year'})
df3['YM'] = df3['YM'].astype(str)
df3['YM'] = df3['YM'] + '00'
df3['YM'] = df3['YM'].astype(int)
df4 = PriceData
df4['RiskFree'] = np.nan
df4['jalaliDate'] = df4['jalaliDate'].astype(int)
for i in df3.YM:
    df4.loc[df4.jalaliDate>= i,'RiskFree'] = df3.loc[df3['YM'] == i ].iloc[0,1]/12/52/7
    
PriceData = df4
PriceData['EMarketRet'] = PriceData['Market_return'] - PriceData['RiskFree']
PriceData['ERet'] = PriceData['Ret'] - PriceData['RiskFree']


n1 = path + "Industry indexes 1399-09-28.csv"
df1 = pd.read_csv(n1)
df1.date = df1.date.apply(vv3)
df1 = df1.drop(columns = ['Unnamed: 0'])
df1 = df1.drop(df1[(df1.index_id == 'EWI')|(df1.index_id == 'overall_index')].index)
df1.index_id = df1.index_id.astype(int)
df1.date = df1.date.astype(int)
gg = df1.groupby('index_id')
df1['gReturn'] = gg['index'].pct_change(periods = 1)*100
fkey = zip(list(df1.index_id),list(df1.date))
mapingdict = dict(zip(fkey,df1['gReturn']))
PriceData['gEReturn'] = PriceData.set_index(['group_id','jalaliDate']).index.map(mapingdict)
PriceData['gEReturn'] = PriceData['gEReturn'] -  PriceData['RiskFree']

# %%
wg = PriceData.groupby(['symbol'])
def FourFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','HML','SMB','Winner_Loser']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['4-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['HML']  + model.params[3]*g['SMB']  + model.params[4]*g['Winner_Loser']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

def FiveFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','HML','SMB','Winner_Loser','gEReturn']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['5-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['HML']  + model.params[3]*g['SMB']  + model.params[4]*g['Winner_Loser'] + model.params[5]*g['gEReturn']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

def TwoFactor(g):
    try:
        y = 'ERet'
        x = ['EMarketRet','gEReturn']
        model = sm.OLS(g[y], sm.add_constant(g[x])).fit()
        g['2-Residual'] = g ['ERet'] - (model.params[0] + model.params[1]*g['EMarketRet'] + model.params[2]*g['gEReturn']) 
    except:
        print(g.symbol.iloc[0])
        g = pd.DataFrame()
    return g

re = wg.apply(FourFactor)
print('Fourfactor done')
re2 = wg.apply(FiveFactor).reset_index(drop = True)
re['5-Residual'] = re2['5-Residual']
print('Fivefactor done')

re2 = wg.apply(TwoFactor).reset_index(drop = True)
re['2-Residual'] = re2['2-Residual']
print('Twofactor done')

re = re.reset_index(drop=True)
col = 'symbol'
re[col] = re[col].apply(lambda x: convert_ar_characters(x))
# Out:
# Fourfactor done
# البرز
# اوان
# اپرداز
# بالاس
# بمپنا
# بمیلا
# بورس
# حاریا
# حخزر
# حفاری
# خبازرس
# خصدرا
# رفاه
# سمگا
# قاسم
# مادیرا
# مبین
# ونیرو
# وهنر
# گدنا
# گشان
# گپارس
# گکوثر
# گکیش
# Fivefactor done
# البرز
# اوان
# اپرداز
# بالاس
# بمپنا
# بمیلا
# بورس
# حاریا
# حخزر
# حفاری
# خبازرس
# خصدرا
# رفاه
# سمگا
# قاسم
# مادیرا
# مبین
# ونیرو
# وهنر
# گدنا
# گشان
# گپارس
# گکوثر
# گکیش
# Twofactor done

# %%
residuals = re[re.jalaliDate>13940000]

# %%
A = set(residuals.symbol)
len(set(residuals.symbol))
# Out:
# 611

# %%
C = set(HolderData.symbol)
len(set(HolderData.symbol))
# Out:
# 612

# %%
HolderData = HolderData[HolderData.symbol.isin(["آسیا",
"اخابر",
"وتجارت",
"وبملت",
"وبصادر",
"البرز"])]

residuals = residuals[residuals.symbol.isin(["آسیا",
"اخابر",
"وتجارت",
"وبملت",
"وبصادر",
"البرز"])]

# %%
A = set(residuals.symbol)
len(set(residuals.symbol))
# Out:
# 6

# %%
C = set(HolderData.symbol)
len(set(HolderData.symbol))
# Out:
# 6

# %%
# HolderData = df

# %%
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['4-Residual']))
HolderData['4-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('4-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['5-Residual']))
HolderData['5-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('5-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['2-Residual']))
HolderData['2-Residual'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('2-Residual done')
fkey = zip(list(residuals.symbol),list(residuals.date))
mapingdict = dict(zip(fkey,residuals['Ret']))
HolderData['Ret'] = HolderData.set_index(['symbol','date']).index.map(mapingdict)
print('Ret done')
# Out:
# 4-Residual done
# 5-Residual done
# 2-Residual done
# Ret done

# %%
# HolderData = HolderData.drop(HolderData[HolderData['4-Residual'].isnull()].index)

# %%
len(HolderData)
# [HolderData['4-Residual'].isnull()]
# Out:
# 66445

# %%
B = set(HolderData.symbol)
len(set(HolderData.symbol))
# Out:
# 6

# %%
HolderData.jalaliDate.iloc[0]
# Out:
# 13940105

# %%
df = HolderData

# %%
Holders = list(set(df.Holder))
Holders.sort()
ids = list(range(len(Holders)))
mapingdict = dict(zip(Holders, ids))
df['Holder_id'] = df['Holder'].map(mapingdict)

symbols = list(set(df.symbol))
symbols.sort()
ids = list(range(len(symbols)))
mapingdict = dict(zip(symbols, ids))
df['id'] = df['symbol'].map(mapingdict)

# %%
df['date1'] = df['date'].apply(vv4)
df['date1'] = pd.to_datetime(df['date1']) 
df['week_of_year'] = df['date1'].dt.week 
df['month_of_year'] = df['date1'].dt.month 
df['year_of_year'] = df['date1'].dt.year

# %%
df['MarketCap'] = df['close_price'] * df['shrout']

# %%
market = df.groupby(['date','symbol']).first().reset_index()[['jalaliDate','date','symbol','MarketCap']]
gm = market.groupby(['date'])

market['Percentile_Rank'] = gm.MarketCap.rank(pct = True) 
fkey = zip(list(market.symbol),list(market.date))
mapingdict = dict(zip(fkey,market['Percentile_Rank']))
df['Percentile_Rank'] = df.set_index(['symbol','date']).index.map(mapingdict)

# %%
df.head()
# Out:
#            date  jalaliDate symbol      stock_id  \
# 54102  20150325    13940105   آسیا  5.110632e+16
# 54103  20150325    13940105   آسیا  5.110632e+16
# 54104  20150325    13940105   آسیا  5.110632e+16
# 54105  20150325    13940105   آسیا  5.110632e+16
# 54106  20150325    13940105   آسیا  5.110632e+16
#
#                                      group_name  group_id  \
# 54102  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
# 54103  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
# 54104  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
# 54105  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
# 54106  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      66.0
#
#                                Holder      nshares        type  Percent  ...  \
# 54102                پرشیا جاوید پویا   45975123.0     private     1.99  ...
# 54103  صندوق بازنشستگی کارکنان بانکها  386564138.0     pension    16.80  ...
# 54104                           ومعین  388590934.0  investment    16.89  ...
# 54105    سرمایه گذاری ای.اف.جی.اچ کیش  435718905.0  investment    18.94  ...
# 54106                   پویا فراز کیش  450749146.0     private    19.59  ...
#
#        2-Residual  Ret Holder_id id      date1 week_of_year  month_of_year  \
# 54102   -0.941136  0.0        63  0 2015-03-25           13              3
# 54103   -0.941136  0.0        38  0 2015-03-25           13              3
# 54104   -0.941136  0.0        59  0 2015-03-25           13              3
# 54105   -0.941136  0.0        21  0 2015-03-25           13              3
# 54106   -0.941136  0.0        64  0 2015-03-25           13              3
#
#        year_of_year     MarketCap  Percentile_Rank
# 54102          2015  3.033700e+12         0.166667
# 54103          2015  3.033700e+12         0.166667
# 54104          2015  3.033700e+12         0.166667
# 54105          2015  3.033700e+12         0.166667
# 54106          2015  3.033700e+12         0.166667
#
# [5 rows x 28 columns]

# %%
df.head()
df.loc[df.week_of_year%2 == 1,'week_of_year'] = df.loc[df.week_of_year%2 == 1]['week_of_year']-1

# %%
    def MonthlyCorr(f):
        
        fc = f.groupby(['year_of_year','month_of_year'])[['2-Residual_x','2-Residual_y',
                                                          '4-Residual_x','4-Residual_y',
                                                          '5-Residual_x','5-Residual_y']].corr().reset_index()
        
        TwoCor = fc.loc[fc.level_2 == '2-Residual_y'][['year_of_year','month_of_year',
                                                       '2-Residual_x']].rename(columns = {'2-Residual_x':'ρ_2'})
        FourCor = fc.loc[fc.level_2 == '4-Residual_y'][['year_of_year','month_of_year',
                                                        '4-Residual_x']].rename(columns = {'4-Residual_x':'ρ_4'})
        ThreeCor = fc.loc[fc.level_2 == '5-Residual_y'][['year_of_year','month_of_year',
                                                         '5-Residual_x']].rename(columns = {'5-Residual_x':'ρ_5'})
        
        TimeId = zip(list(TwoCor.year_of_year),list(TwoCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(TwoCor.ρ_2)))
        f['Monthlyρ_2'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(FourCor.year_of_year),list(FourCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(FourCor.ρ_4)))
        f['Monthlyρ_4'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(ThreeCor.year_of_year),list(ThreeCor.month_of_year))
        mapingdict = dict(zip(TimeId,list(ThreeCor.ρ_5)))
        f['Monthlyρ_5'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict) 
        return f
    
            
    def MonthlyCalculation(f):
    
        f = MonthlyCorr(f)        
        
        ff = f.groupby(['year_of_year','month_of_year'])[['SizeRatio','MarketCap_x',
                                                          'MarketCap_y','Percentile_Rank_x',
                                                       'Percentile_Rank_y','size1','size2',
                                                          'SameSize']].mean().reset_index()
        
        vlist = ['SizeRatio', 'MarketCap_x','MarketCap_y', 'Percentile_Rank_x', 'Percentile_Rank_y', 'size1',
               'size2', 'SameSize']
        
        for i in vlist:
            TimeId = zip(list(ff.year_of_year),list(ff.month_of_year))
            mapingdict = dict(zip(TimeId,list(ff[i])))
            f['Monthly'+i] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        
        mfcapf =  f.groupby(['year_of_year','month_of_year'])['FCAPf','FCA'].mean().reset_index()
        TimeId = zip(list(mfcapf.year_of_year),list(mfcapf.month_of_year))
        mapingdict = dict(zip(TimeId,list(mfcapf.FCAPf)))
        f['MonthlyFCAPf'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
        TimeId = zip(list(mfcapf.year_of_year),list(mfcapf.month_of_year))
        mapingdict = dict(zip(TimeId,list(mfcapf.FCA)))
        f['MonthlyFCA'] = f.set_index(['year_of_year','month_of_year']).index.map(mapingdict)
                
        f['Monthlyρ_2_f'] = f['Monthlyρ_2'].shift(-1)
        f['Monthlyρ_4_f'] = f['Monthlyρ_4'].shift(-1)
        f['Monthlyρ_5_f'] = f['Monthlyρ_5'].shift(-1)
        return f

# %%
    def WeeklyCorr(f):
        fc = f.groupby(['year_of_year','week_of_year'])[['2-Residual_x','2-Residual_y',
                                                         '4-Residual_x','4-Residual_y',
                                                         '5-Residual_x','5-Residual_y']].corr().reset_index()
        
        TwoCor = fc.loc[fc.level_2 == '2-Residual_y'][['year_of_year','week_of_year',
                                                        '2-Residual_x']].rename(columns = {'2-Residual_x':'ρ_2'})
        FourCor = fc.loc[fc.level_2 == '4-Residual_y'][['year_of_year','week_of_year',
                                                        '4-Residual_x']].rename(columns = {'4-Residual_x':'ρ_4'})
        ThreeCor = fc.loc[fc.level_2 == '5-Residual_y'][['year_of_year','week_of_year',
                                                         '5-Residual_x']].rename(columns = {'5-Residual_x':'ρ_5'})
        
        TimeId = zip(list(TwoCor.year_of_year),list(TwoCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(TwoCor.ρ_2)))
        f['Weeklyρ_2'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(FourCor.year_of_year),list(FourCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(FourCor.ρ_4)))
        f['Weeklyρ_4'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        TimeId = zip(list(ThreeCor.year_of_year),list(ThreeCor.week_of_year))
        mapingdict = dict(zip(TimeId,list(ThreeCor.ρ_5)))
        f['Weeklyρ_5'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)
        
        return f
    
        
    def WeeklyCalculation(f):
        
        f = WeeklyCorr(f)


        ff = f.groupby(['year_of_year','week_of_year'])[['SizeRatio','MarketCap_x','MarketCap_y','Percentile_Rank_x',
                                                       'Percentile_Rank_y','size1','size2','SameSize']].mean().reset_index()
        
        vlist = ['SizeRatio', 'MarketCap_x','MarketCap_y', 'Percentile_Rank_x', 'Percentile_Rank_y', 'size1',
               'size2', 'SameSize']
        
        for i in vlist:
            TimeId = zip(list(ff.year_of_year),list(ff.week_of_year))
            mapingdict = dict(zip(TimeId,list(ff[i])))
            f['Weekly'+i] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict) 



        wfcapf =  f.groupby(['year_of_year','week_of_year'])['FCAPf','FCA'].mean().reset_index()
        TimeId = zip(list(wfcapf.year_of_year),list(wfcapf.week_of_year))
        mapingdict = dict(zip(TimeId,list(wfcapf.FCAPf)))
        f['WeeklyFCAPf'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict)  
        TimeId = zip(list(wfcapf.year_of_year),list(wfcapf.week_of_year))
        mapingdict = dict(zip(TimeId,list(wfcapf.FCA)))
        f['WeeklyFCA'] = f.set_index(['year_of_year','week_of_year']).index.map(mapingdict) 
        f['Weeklyρ_2_f'] = f['Weeklyρ_2'].shift(-1)
        f['Weeklyρ_4_f'] = f['Weeklyρ_4'].shift(-1)
        f['Weeklyρ_5_f'] = f['Weeklyρ_5'].shift(-1)
        return f

# %%
def FCalculatio(a,g,S_g):
    if len(a) == 0:
        a = pd.DataFrame()
        return a
    else: 
        a['FCAPf'] = (a['nshares_x']*a['close_price_x'] + a['nshares_y']*a['close_price_y'])/(a['shrout_x']*a['close_price_x'] + a['shrout_y']*a['close_price_y'])
        a['FCA'] = ((a['nshares_x']*a['close_price_x'])**0.5 + (a['nshares_y']*a['close_price_y'])**0.5)/((a['shrout_x']*a['close_price_x'])**0.5 + (a['shrout_y']*a['close_price_y'])**0.5)
    return a

# %%
    def Calculation(g,S_g):
        intersection = list(set.intersection(set(S_g.date), set(g.date)))
        g = g.loc[g.date.isin(intersection)]
        S_g = S_g.loc[S_g.date.isin(intersection)]
        a = g.merge(S_g , on = ['date','jalaliDate','week_of_year','month_of_year','year_of_year'])
        a = FCalculatio(a,g,S_g)
        if len(a) == 0:
            f = pd.DataFrame()
            return f
        a['SizeRatio'] = (a['MarketCap_x'])/(a['MarketCap_y'])
        f = a.groupby(['date','jalaliDate','id_x','id_y','week_of_year','month_of_year','year_of_year',
                           'group_name_x','group_name_y','Ret_x','Ret_y','SizeRatio','MarketCap_x',
                           'MarketCap_y','2-Residual_x','2-Residual_y','4-Residual_x','4-Residual_y',
                           '5-Residual_x','5-Residual_y','Percentile_Rank_x','Percentile_Rank_y'])['FCAPf','FCA'].sum().reset_index()
        f['FCA'] = f['FCA']**2
        f['size1'] = 0
        f.loc[f.MarketCap_x>f.MarketCap_y,'size1'] = f[f.MarketCap_x>f.MarketCap_y]['Percentile_Rank_x']
        f.loc[f.MarketCap_x<f.MarketCap_y,'size1'] = f[f.MarketCap_x<f.MarketCap_y]['Percentile_Rank_y']
        f['size2'] = 0
        f.loc[f.MarketCap_x>f.MarketCap_y,'size2'] = f[f.MarketCap_x>f.MarketCap_y]['Percentile_Rank_y']
        f.loc[f.MarketCap_x<f.MarketCap_y,'size2'] = f[f.MarketCap_x<f.MarketCap_y]['Percentile_Rank_x']
        f['SameSize'] =  f['size2'] -f['size1']
        f['sgroup'] = 0
        f.loc[f.group_name_x == f.group_name_y,'sgroup'] = 1
        return f

# %%
gdata = df.groupby(['id'])
g = gdata.get_group(0)
S_g = gdata.get_group(1)

def FCAPf(S_g,g):
    intersection = list(set.intersection(set(S_g.date), set(g.date)))
    if len(intersection) == 0 :
#         print('0')
        return
    f= Calculation(g,S_g)
    if len (f) == 0:
#         print("No")
        return
    f = MonthlyCalculation(f)        
    f = WeeklyCalculation(f)
    return f

FCAPf(S_g,g)
# Out:
#           date  jalaliDate  id_x  id_y  week_of_year  month_of_year  \
# 0     20150325    13940105     0     1            12              3
# 1     20150328    13940108     0     1            12              3
# 2     20150329    13940109     0     1            12              3
# 3     20150330    13940110     0     1            14              3
# 4     20150331    13940111     0     1            14              3
# 5     20150404    13940115     0     1            14              4
# 6     20150405    13940116     0     1            14              4
# 7     20150406    13940117     0     1            14              4
# 8     20150407    13940118     0     1            14              4
# 9     20150408    13940119     0     1            14              4
# 10    20150411    13940122     0     1            14              4
# 11    20150412    13940123     0     1            14              4
# 12    20150413    13940124     0     1            16              4
# 13    20150414    13940125     0     1            16              4
# 14    20150415    13940126     0     1            16              4
# 15    20150418    13940129     0     1            16              4
# 16    20150419    13940130     0     1            16              4
# 17    20150420    13940131     0     1            16              4
# 18    20150421    13940201     0     1            16              4
# 19    20150422    13940202     0     1            16              4
# 20    20150425    13940205     0     1            16              4
# 21    20150426    13940206     0     1            16              4
# 22    20150427    13940207     0     1            18              4
# 23    20150428    13940208     0     1            18              4
# 24    20150429    13940209     0     1            18              4
# 25    20150503    13940213     0     1            18              5
# 26    20150504    13940214     0     1            18              5
# 27    20150505    13940215     0     1            18              5
# 28    20150506    13940216     0     1            18              5
# 29    20150509    13940219     0     1            18              5
# ...        ...         ...   ...   ...           ...            ...
# 1104  20200921    13990631     0     1            38              9
# 1105  20200922    13990701     0     1            38              9
# 1106  20200923    13990702     0     1            38              9
# 1107  20200926    13990705     0     1            38              9
# 1108  20200927    13990706     0     1            38              9
# 1109  20200928    13990707     0     1            40              9
# 1110  20200929    13990708     0     1            40              9
# 1111  20200930    13990709     0     1            40              9
# 1112  20201003    13990712     0     1            40             10
# 1113  20201004    13990713     0     1            40             10
# 1114  20201005    13990714     0     1            40             10
# 1115  20201006    13990715     0     1            40             10
# 1116  20201007    13990716     0     1            40             10
# 1117  20201010    13990719     0     1            40             10
# 1118  20201011    13990720     0     1            40             10
# 1119  20201012    13990721     0     1            42             10
# 1120  20201013    13990722     0     1            42             10
# 1121  20201014    13990723     0     1            42             10
# 1122  20201018    13990727     0     1            42             10
# 1123  20201019    13990728     0     1            42             10
# 1124  20201020    13990729     0     1            42             10
# 1125  20201021    13990730     0     1            42             10
# 1126  20201024    13990803     0     1            42             10
# 1127  20201026    13990805     0     1            44             10
# 1128  20201027    13990806     0     1            44             10
# 1129  20201028    13990807     0     1            44             10
# 1130  20201031    13990810     0     1            44             10
# 1131  20201101    13990811     0     1            44             11
# 1132  20201102    13990812     0     1            44             11
# 1133  20201104    13990814     0     1            44             11
#
#       year_of_year                              group_name_x group_name_y  \
# 0             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 2             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 3             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 4             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 5             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 6             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 7             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 8             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 9             2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 10            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 11            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 12            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 13            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 14            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 15            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 16            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 17            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 18            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 19            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 20            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 21            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 22            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 23            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 24            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 25            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 26            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 27            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 28            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 29            2015  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# ...            ...                                       ...          ...
# 1104          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1105          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1106          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1107          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1108          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1109          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1110          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1111          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1112          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1113          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1114          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1115          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1116          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1117          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1118          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1119          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1120          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1121          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1122          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1123          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1124          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1125          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1126          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1127          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1128          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1129          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1130          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1131          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1132          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
# 1133          2020  بیمه وصندوق بازنشستگی به جزتامین اجتماعی      مخابرات
#
#          Ret_x  ...  WeeklyPercentile_Rank_x  WeeklyPercentile_Rank_y  \
# 0     0.000000  ...                 0.166667                 1.000000
# 1     0.454890  ...                 0.166667                 1.000000
# 2     3.849057  ...                 0.166667                 1.000000
# 3    -0.436047  ...                 0.166667                 1.000000
# 4    -0.072993  ...                 0.166667                 1.000000
# 5     1.533966  ...                 0.166667                 1.000000
# 6     3.956835  ...                 0.166667                 1.000000
# 7    -2.491349  ...                 0.166667                 1.000000
# 8    -3.761533  ...                 0.166667                 1.000000
# 9     2.654867  ...                 0.166667                 1.000000
# 10   -0.502874  ...                 0.166667                 1.000000
# 11   -0.866426  ...                 0.166667                 1.000000
# 12   -0.145666  ...                 0.166667                 1.000000
# 13   -2.261123  ...                 0.166667                 1.000000
# 14   -0.223881  ...                 0.166667                 1.000000
# 15    3.590127  ...                 0.166667                 1.000000
# 16    1.516245  ...                 0.166667                 1.000000
# 17   -1.280228  ...                 0.166667                 1.000000
# 18   -0.720461  ...                 0.166667                 1.000000
# 19   -3.846154  ...                 0.166667                 1.000000
# 20    0.150943  ...                 0.166667                 1.000000
# 21    0.000000  ...                 0.166667                 1.000000
# 22   -0.376790  ...                 0.166667                 1.000000
# 23   -1.134644  ...                 0.166667                 1.000000
# 24   -0.688600  ...                 0.166667                 1.000000
# 25   -0.770416  ...                 0.166667                 1.000000
# 26   -0.698758  ...                 0.166667                 1.000000
# 27   -1.720094  ...                 0.166667                 1.000000
# 28   -3.500398  ...                 0.166667                 1.000000
# 29   -0.164880  ...                 0.166667                 1.000000
# ...        ...  ...                      ...                      ...
# 1104 -4.207733  ...                 0.316667                 0.916667
# 1105  2.690938  ...                 0.316667                 0.916667
# 1106  4.778420  ...                 0.316667                 0.916667
# 1107  4.413387  ...                 0.316667                 0.916667
# 1108 -3.768933  ...                 0.316667                 0.916667
# 1109 -2.196193  ...                 0.333333                 0.833333
# 1110 -4.229042  ...                 0.333333                 0.833333
# 1111  2.618210  ...                 0.333333                 0.833333
# 1112  4.760091  ...                 0.333333                 0.833333
# 1113 -1.890222  ...                 0.333333                 0.833333
# 1114  0.703964  ...                 0.333333                 0.833333
# 1115  4.782929  ...                 0.333333                 0.833333
# 1116  4.705056  ...                 0.333333                 0.833333
# 1117  4.225352  ...                 0.333333                 0.833333
# 1118 -0.482625  ...                 0.333333                 0.833333
# 1119 -3.976722  ...                 0.312500                 0.833333
# 1120  0.740741  ...                 0.312500                 0.833333
# 1121 -3.275401  ...                 0.312500                 0.833333
# 1122 -4.906704  ...                 0.312500                 0.833333
# 1123 -0.835756  ...                 0.312500                 0.833333
# 1124 -4.470502  ...                 0.312500                 0.833333
# 1125  1.380898  ...                 0.312500                 0.833333
# 1126 -3.556565  ...                 0.312500                 0.833333
# 1127 -0.666928  ...                 0.166667                 0.833333
# 1128 -4.541864  ...                 0.166667                 0.833333
# 1129 -4.923459  ...                 0.166667                 0.833333
# 1130  4.656223  ...                 0.166667                 0.833333
# 1131 -3.367983  ...                 0.166667                 0.833333
# 1132 -3.399312  ...                 0.166667                 0.833333
# 1133  1.425390  ...                 0.166667                 0.833333
#
#       Weeklysize1  Weeklysize2  WeeklySameSize  WeeklyFCAPf   WeeklyFCA  \
# 0        1.000000     0.166667       -0.833333     3.154349   36.413846
# 1        1.000000     0.166667       -0.833333     3.154349   36.413846
# 2        1.000000     0.166667       -0.833333     3.154349   36.413846
# 3        1.000000     0.166667       -0.833333     3.155803   36.441467
# 4        1.000000     0.166667       -0.833333     3.155803   36.441467
# 5        1.000000     0.166667       -0.833333     3.155803   36.441467
# 6        1.000000     0.166667       -0.833333     3.155803   36.441467
# 7        1.000000     0.166667       -0.833333     3.155803   36.441467
# 8        1.000000     0.166667       -0.833333     3.155803   36.441467
# 9        1.000000     0.166667       -0.833333     3.155803   36.441467
# 10       1.000000     0.166667       -0.833333     3.155803   36.441467
# 11       1.000000     0.166667       -0.833333     3.155803   36.441467
# 12       1.000000     0.166667       -0.833333     3.155005   36.426340
# 13       1.000000     0.166667       -0.833333     3.155005   36.426340
# 14       1.000000     0.166667       -0.833333     3.155005   36.426340
# 15       1.000000     0.166667       -0.833333     3.155005   36.426340
# 16       1.000000     0.166667       -0.833333     3.155005   36.426340
# 17       1.000000     0.166667       -0.833333     3.155005   36.426340
# 18       1.000000     0.166667       -0.833333     3.155005   36.426340
# 19       1.000000     0.166667       -0.833333     3.155005   36.426340
# 20       1.000000     0.166667       -0.833333     3.155005   36.426340
# 21       1.000000     0.166667       -0.833333     3.155005   36.426340
# 22       1.000000     0.166667       -0.833333     3.155235   36.430528
# 23       1.000000     0.166667       -0.833333     3.155235   36.430528
# 24       1.000000     0.166667       -0.833333     3.155235   36.430528
# 25       1.000000     0.166667       -0.833333     3.155235   36.430528
# 26       1.000000     0.166667       -0.833333     3.155235   36.430528
# 27       1.000000     0.166667       -0.833333     3.155235   36.430528
# 28       1.000000     0.166667       -0.833333     3.155235   36.430528
# 29       1.000000     0.166667       -0.833333     3.155235   36.430528
# ...           ...          ...             ...          ...         ...
# 1104     0.916667     0.316667       -0.600000     5.669509  156.021154
# 1105     0.916667     0.316667       -0.600000     5.669509  156.021154
# 1106     0.916667     0.316667       -0.600000     5.669509  156.021154
# 1107     0.916667     0.316667       -0.600000     5.669509  156.021154
# 1108     0.916667     0.316667       -0.600000     5.669509  156.021154
# 1109     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1110     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1111     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1112     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1113     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1114     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1115     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1116     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1117     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1118     0.833333     0.333333       -0.500000     5.106733  129.298131
# 1119     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1120     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1121     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1122     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1123     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1124     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1125     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1126     0.833333     0.312500       -0.520833     4.940058  116.706897
# 1127     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1128     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1129     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1130     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1131     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1132     0.833333     0.166667       -0.666667     4.884140   97.708120
# 1133     0.833333     0.166667       -0.666667     4.884140   97.708120
#
#       Weeklyρ_2_f  Weeklyρ_4_f  Weeklyρ_5_f
# 0       -0.808569     0.980103    -0.263754
# 1       -0.808569     0.980103    -0.263754
# 2        0.583709     0.530611     0.424334
# 3        0.583709     0.530611     0.424334
# 4        0.583709     0.530611     0.424334
# 5        0.583709     0.530611     0.424334
# 6        0.583709     0.530611     0.424334
# 7        0.583709     0.530611     0.424334
# 8        0.583709     0.530611     0.424334
# 9        0.583709     0.530611     0.424334
# 10       0.583709     0.530611     0.424334
# 11      -0.234081    -0.055428    -0.283842
# 12      -0.234081    -0.055428    -0.283842
# 13      -0.234081    -0.055428    -0.283842
# 14      -0.234081    -0.055428    -0.283842
# 15      -0.234081    -0.055428    -0.283842
# 16      -0.234081    -0.055428    -0.283842
# 17      -0.234081    -0.055428    -0.283842
# 18      -0.234081    -0.055428    -0.283842
# 19      -0.234081    -0.055428    -0.283842
# 20      -0.234081    -0.055428    -0.283842
# 21       0.268114    -0.085130     0.289094
# 22       0.268114    -0.085130     0.289094
# 23       0.268114    -0.085130     0.289094
# 24       0.268114    -0.085130     0.289094
# 25       0.268114    -0.085130     0.289094
# 26       0.268114    -0.085130     0.289094
# 27       0.268114    -0.085130     0.289094
# 28       0.268114    -0.085130     0.289094
# 29       0.268114    -0.085130     0.289094
# ...           ...          ...          ...
# 1104     0.484997    -0.472904     0.406587
# 1105     0.484997    -0.472904     0.406587
# 1106     0.484997    -0.472904     0.406587
# 1107     0.484997    -0.472904     0.406587
# 1108    -0.032547     0.498657    -0.045400
# 1109    -0.032547     0.498657    -0.045400
# 1110    -0.032547     0.498657    -0.045400
# 1111    -0.032547     0.498657    -0.045400
# 1112    -0.032547     0.498657    -0.045400
# 1113    -0.032547     0.498657    -0.045400
# 1114    -0.032547     0.498657    -0.045400
# 1115    -0.032547     0.498657    -0.045400
# 1116    -0.032547     0.498657    -0.045400
# 1117    -0.032547     0.498657    -0.045400
# 1118     0.071523     0.071454    -0.073647
# 1119     0.071523     0.071454    -0.073647
# 1120     0.071523     0.071454    -0.073647
# 1121     0.071523     0.071454    -0.073647
# 1122     0.071523     0.071454    -0.073647
# 1123     0.071523     0.071454    -0.073647
# 1124     0.071523     0.071454    -0.073647
# 1125     0.071523     0.071454    -0.073647
# 1126     0.423824     0.900689     0.601724
# 1127     0.423824     0.900689     0.601724
# 1128     0.423824     0.900689     0.601724
# 1129     0.423824     0.900689     0.601724
# 1130     0.423824     0.900689     0.601724
# 1131     0.423824     0.900689     0.601724
# 1132     0.423824     0.900689     0.601724
# 1133          NaN          NaN          NaN
#
# [1134 rows x 60 columns]

# %%
len(set(df.symbol))
# Out:
# 6

# %%
data = pd.DataFrame()
for i in ['آسیا',
         'اخابر']:
    g = df[df.symbol == i]
    print(i)
    for k in ["وتجارت","وبملت",
             "وبصادر","البرز"]:
        t = pd.DataFrame()
        print(k)
        S_g = df[df.symbol == k]
        t = FCAPf(S_g,g)
        data = data.append(t)
# Out:
# آسیا
# اخابر

# %%
d = data.reset_index(drop = True)

# %%
symbols = list(set(df.symbol))
symbols.sort()
ids = list(range(len(symbols)))
mapingdict = dict(zip(ids,symbols))
d['symbol_x'] = d['id_x'].map(mapingdict)
d['symbol_y'] = d['id_y'].map(mapingdict)

# %%
def add(row):
    if len(row)<2:
        row = '0'+ row
    return row
d['month_of_year'] = d['month_of_year'].astype(str).apply(add )
d['week_of_year'] = d['week_of_year'].astype(str).apply(add )


d['year_of_year'] = d['year_of_year'].astype(str)

d['Year_Month_week'] = d['year_of_year'] + d['week_of_year']
d['Year_Month'] = d['year_of_year'] + d['month_of_year']

days = list(set(d.date))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t'] = d['date'].map(mapingdict)

days = list(set(d.Year_Month_week))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t_Week'] = d['Year_Month_week'].map(mapingdict)

days = list(set(d.Year_Month))
days.sort()
t = list(range(len(days)))
mapingdict = dict(zip(days, t))
d['t_Month'] = d['Year_Month'].map(mapingdict)


d['id'] = d['symbol_x'] + d['symbol_y']
ids = list(set(d.id))
ids.sort()
id = list(range(len(ids)))
mapingdict = dict(zip(ids, id))
d['id'] = d['id'].map(mapingdict)

def NormalTransform(df_sub):
    col = df_sub.transform('rank')
    return (col-col.mean())/col.std()


gg = d.groupby(['t'])
d['FCAP*'] = gg['FCAPf'].apply(NormalTransform)
d['FCA*'] = gg['FCA'].apply(NormalTransform)

gg = d.groupby(['t_Week'])
d['WeeklyFCAP*'] = gg['WeeklyFCAPf'].apply(NormalTransform)
d['WeeklyFCA*'] = gg['WeeklyFCA'].apply(NormalTransform)

gg = d.groupby(['t_Month'])
d['MonthlyFCAP*'] = gg['MonthlyFCAPf'].apply(NormalTransform) 
d['MonthlyFCA*'] = gg['MonthlyFCA'].apply(NormalTransform)

# %%
d[d.jalaliDate == 13990214][['t','t_Week','t_Month']]
# Out:
#          t  t_Week  t_Month
# 836   1228     138       62
# 1878  1228     138       62
# 2717  1228     138       62
# 4831  1228     138       62
# 5775  1228     138       62
# 6536  1228     138       62

# %%
d['EventDay'] = 1228
d['WEventDay'] = 138
d['MEventDay'] = 62
d["jalaliDate"] = d["jalaliDate"].astype(int)
d['Period'] = d['t'] - d['EventDay']
d['WPeriod'] = d['t_Week'] - d['WEventDay']
d['MPeriod'] = d['t_Month'] - d['MEventDay']

# %%
d[(d.jalaliDate == 13971214)]
# Out:
#           date  jalaliDate  id_x  id_y week_of_year month_of_year  \
# 597   20190305    13971214     0     5           10            03
# 1683  20190305    13971214     0     4           10            03
# 2478  20190305    13971214     0     3           10            03
# 3712  20190305    13971214     0     2           10            03
#
#      year_of_year                              group_name_x  \
# 597          2019  بیمه وصندوق بازنشستگی به جزتامین اجتماعی
# 1683         2019  بیمه وصندوق بازنشستگی به جزتامین اجتماعی
# 2478         2019  بیمه وصندوق بازنشستگی به جزتامین اجتماعی
# 3712         2019  بیمه وصندوق بازنشستگی به جزتامین اجتماعی
#
#                                   group_name_y     Ret_x  ...  WeeklyFCAP*  \
# 597                    بانکها و موسسات اعتباری -1.707317  ...    -0.277007
# 1683                   بانکها و موسسات اعتباری -1.707317  ...    -1.218829
# 2478                   بانکها و موسسات اعتباری -1.707317  ...     0.387809
# 3712  بیمه وصندوق بازنشستگی به جزتامین اجتماعی -1.707317  ...     1.218829
#
#       WeeklyFCA*  MonthlyFCAP*  MonthlyFCA*  EventDay  Period  WEventDay  \
# 597    -0.831020     -0.233681    -1.034875      1228    -275        138
# 1683    1.218829     -1.168407     1.168407      1228    -275        138
# 2478   -1.495836      0.300448    -1.569004      1228    -275        138
# 3712    0.110803      1.168407    -0.100149      1228    -275        138
#
#       MEventDay  WPeriod  MPeriod
# 597          62      -31      -14
# 1683         62      -31      -14
# 2478         62      -31      -14
# 3712         62      -31      -14
#
# [4 rows x 80 columns]

# %%
d = d[~d.Period.isnull()]

# %%
d = d[d.Period > -2 * d.Period.max()]

# %%
set(d.id)
# Out:
# {2, 4, 9, 13, 16, 18, 40, 50}

# %%
d.head().columns
n3 = path + 'DaraNormalzedFCAP1.0.csv'
d.to_csv(n3,index = False)
print('d done')
a = d.drop_duplicates(['t','id'])
n3 = path + 'DaraNormalzedFCAP1.1.csv'
a.to_csv(n3,index = False)

Montly =  a.drop_duplicates(['id','t_Month'],keep = "last")
n3 = path + 'DaraMonthlyNormalzedFCAP1.1.csv'
Montly.to_csv(n3,index = False)

n3 = path + 'DaraWeeklyNormalzedFCAP1.1.csv'
Weekly = a.drop_duplicates(['id','t_Week'],keep = "last")
Weekly.to_csv(n3,index = False)
# Out:
# d done

# %%
path
# Out:
# 'H:\\Economics\\Finance(Prof.Heidari-Aghajanzadeh)\\Data\\\\'
